# %%
# %matplotlib notebook
import numpy as np
from scipy import sparse, linalg
import matplotlib.pyplot as plt
from scipy.misc import derivative
#from scipy import optimize
import sys
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from amfe.frequency_module.frequency import cos_bases_for_MHBM, create_Z_matrix, linear_harmonic_force, hbm_complex_bases
from amfe.optimize import optimize
from ipywidgets import interact
from matplotlib.animation import FuncAnimation, writers
import matplotlib.animation as animation


plt.rcParams.update({'font.size': 14})


#B = cos_bases_for_MHBM(1,number_of_harm=1,static=False)
nH = 3
n_points = 1000
q = hbm_complex_bases(1,number_of_harm=nH,n_points=n_points,static=False,normalized=False)

fig = plt.figure(figsize=(10,5))
for i in range(q.shape[1]):
#for i in range(2):
    plt.plot(q[:,i].real,'--',label='real Harm ' + str(i))
    plt.plot(q[:,i].imag,'--',label='imag Harm ' + str(i))
 
plt.legend(loc='upper right')
plt.show()
# Out:
# Python was not able to load the fast fortran assembly routines.
#
# Python was not able to load the fast fortran material routines.
# <div id='6742a82c-4398-4322-b108-6f6f0b267599'></div>

# %%
amplitude_dof_2 = 1.0
Bc = np.array([0,1]) # dof section ma
P = np.array([0.0,amplitude_dof_2], dtype = np.complex)
beta = 2.0
m1 = 1.0
m2 = m1
k1 = 1.0
k2 = k1
c1 = 0.05
c2 = c1

K = np.array([[k1+k2, -k2],
              [-k2,k2]])

M = np.array([[m1,0.0],
              [0.0,m2]])

C = np.array([[c1+c2,-c2],
              [-c2,c2]])

n_dofs = K.shape[0] 
I = np.eye(n_dofs)
I_harm = np.eye(nH)
#Q = np.kron(q ,[1]*nH)
Q = np.kron(I,q[:,0])
for i in range(1,nH):
    Q = np.concatenate([Q,np.kron(I,q[:,i])])
Q = Q.T

P_aug = list(0*P)*nH
P_aug[0:n_dofs] = list(P)
P_aug = np.array(P_aug)
Bc_aug = sparse.kron(I_harm,Bc)
#fl = linear_harmonic_force(P, f0 = 1, n_points=50, cos=True)
fl = Q.dot(P_aug).real
#fl = np.kron(I.toarray().dot(P),q).real

fig = plt.figure(figsize=(10,5))
for i in range(int(fl.shape[0]/n_points)):
    plt.plot(fl[i*n_points:(i+1)*n_points].real,'o-',label='real Force in dof ' + str(i))
    plt.plot(fl[i*n_points:(i+1)*n_points].imag,'.-',label='imag force in dof ' + str(i))
 
plt.legend(loc='upper right')
plt.show()
# Out:
# <div id='2dda5503-9713-4129-b85e-6223ae697552'></div>

# %%
plt.figure()
plt.plot(fl.real,'b--')
plt.plot(fl.imag,'r--')
# Out:
# <div id='dd359f95-c588-49e6-9173-dc0d3c452ef4'></div>

# %%
print(Q.shape)

plt.figure()
plt.plot(Q[:,0].real)
# Out:
# (2000, 6)
# <div id='46667b32-198a-4ce0-9018-478b991e279f'></div>

# %%
fl_ = Q.conj().T.dot(fl) # force in frequency domain
fl_
# Out:
# array([0.   +0.00000000e+00j, 1.001-5.23394364e-17j,
#        0.   +0.00000000e+00j, 0.002-2.67992754e-17j,
#        0.   +0.00000000e+00j, 0.002-1.85279987e-17j])

# %%
fl_ = Q.conj().T.dot(fl) # force in frequency domain
fl_ = Bc_aug.T.dot(Bc_aug.dot(fl_))

fnl = lambda u : beta*(u**3)
fnl_ = lambda u_ : Bc_aug.T.dot(Bc_aug.dot(Q.conj().T.dot(fnl(Q.dot(u_).real)) - fl_))
Z = lambda w :create_Z_matrix(K,C,M,f0= w/(2.0*np.pi),nH=nH, static=False)
#Z = lambda w: np.array([-(w)**2*M + 1J*(w)*C + K]) 
R = lambda u_, w : Z(w).dot(u_) + fnl_(u_)

# %%
# %%time
x0 = np.array([0.0]*n_dofs*nH,dtype=np.complex)
y_d, p_d, info_dict = optimize.continuation(R,x0=x0,p_range=(0.01,3.0), p0=0.1, max_int=2000, max_dp=0.5,step=0.1, max_int_corr=200, tol=1.0E-10)
y_d = y_d*(P[1]/fl_.real[1])
# Out:
# Using iterative solver = 879807663664350625792.000000
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\extrapolation.py:443: RuntimeWarning: invalid value encountered in less_equal
#   converged = err <= tol
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numpy\lib\nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:150: RuntimeWarning: invalid value encountered in less
#   outliers = (((abs(der) < (a_median / trim_fact)) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:151: RuntimeWarning: invalid value encountered in greater
#   (abs(der) > (a_median * trim_fact))) * (a_median > 1e-8) +
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:152: RuntimeWarning: invalid value encountered in less
#   ((der < p25-1.5*iqr) + (p75+1.5*iqr < der)))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\limits.py:126: UserWarning: All-NaN slice encountered
#   warnings.warn(str(msg))
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in multiply
#   after removing the cwd from sys.path.
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\step_generators.py:102: RuntimeWarning: invalid value encountered in greater
#   if (np.abs(step) > 0).all():
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# c:\amfe\amfe\optimize\optimize.py in continuation(fun, x0, p_range, p0, jacx, jacp, step, max_int, max_int_corr, tol, max_dp, correction_method, root_method, print_mode)
#     478         # corrector algotirhm
#     479         if correction_method=='moore_penrose':
# --> 480             y,v,error_norm, error_list, success = moore_penrose(fun_real,y_pred,v0,G,Gy,R,b,max_int=max_int_corr,tol=tol)
#     481
#     482         elif correction_method=='matcont':
#
# c:\amfe\amfe\optimize\optimize.py in moore_penrose(fun, y0, v0, G, Gy, R, b, max_int, tol)
#     665         y -= delta_y
#     666         # update tangent vector at new y = [x,p]
# --> 667         R_eval = R(y,v)
#     668         Gy_eval = Gy(y,v)
#     669
#
# c:\amfe\amfe\optimize\optimize.py in <lambda>(y, v)
#     456     Gy = lambda y, v : np.vstack((np.hstack((hx(y),hp(y).T)),v))
#     457     G = lambda y, v : np.concatenate((fun_real(y[:-1],y[-1]),np.array([0.0])))
# --> 458     R = lambda y, v : np.concatenate((np.hstack((hx(y),hp(y).T)).dot(v),np.array([0.0])))
#     459
#     460     # find initial fixed point for continuation
#
# c:\amfe\amfe\optimize\optimize.py in <lambda>(y)
#     448
#     449     #build jacobian aprox. where y = [x,p]
# --> 450     hx = lambda y : JFx(y[-1])(y[:-1])
#     451     hp = lambda y : JFp(y[:-1])(y[-1])
#     452     fun_norm = lambda y : np.linalg.norm(fun_real(y[:-1],y[-1]))
#
# ~\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\core.py in __call__(self, x, *args, **kwds)
#     665
#     666     def __call__(self, x, *args, **kwds):
# --> 667         return super(Jacobian, self).__call__(np.atleast_1d(x), *args, **kwds)
#     668
#     669
#
# ~\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\core.py in __call__(self, x, *args, **kwds)
#     296     def __call__(self, x, *args, **kwds):
#     297         xi = np.asarray(x)
# --> 298         results = self._derivative(xi, args, kwds)
#     299         derivative, info = self._extrapolate(*results)
#     300         if self.full_output:
#
# ~\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\core.py in _derivative_nonzero_order(self, xi, args, kwds)
#     662
#     663         self.set_richardson_rule(step_ratio, self.richardson_terms)
# --> 664         return self._apply_fd_rule(step_ratio, results, steps2)
#     665
#     666     def __call__(self, x, *args, **kwds):
#
# ~\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\core.py in _apply_fd_rule(self, step_ratio, sequence, steps)
#     392         n
#     393         """
# --> 394         f_del, h, original_shape = self._vstack(sequence, steps)
#     395         fd_rule = self._get_finite_difference_rule(step_ratio)
#     396         ne = h.shape[0]
#
# ~\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\numdifftools\core.py in _vstack(self, sequence, steps)
#     589
#     590     def _vstack(self, sequence, steps):
# --> 591         original_shape = list(np.shape(np.atleast_1d(sequence[0].squeeze())))
#     592         ndim = len(original_shape)
#     593         axes = [0, 1, 2][:ndim]
#
# IndexError: list index out of range

# %%
dof_id = 0

fig, ax1 = plt.subplots(1)
max_x = np.abs(p_d).max()
min_x = np.abs(p_d).min()
max_y = np.abs(y_d[dof_id]).max()
min_y = np.abs(y_d[dof_id]).min()

factor = 0.1
lim = lambda x, factor  : x + np.sign(x)*factor*x

ax1.set_xlim([lim(min_x,-factor)   ,lim(max_x,factor)])
ax1.set_ylim([lim(min_y,-factor)   ,lim(max_y,factor)])


def update(i):
    legend = True
    ax1.clear()
    ax1.plot(p_d[i],np.abs(y_d[0][i]),'ro',markerfacecolor='y')
    ax1.plot(p_d[:i],np.abs(y_d[0][:i]),'k.',label='dof 1')
    ax1.plot(p_d[i],np.abs(y_d[1][i]),'ro',markerfacecolor='y')
    ax1.plot(p_d[:i],np.abs(y_d[1][:i]),'b.',label='dof 2')
    ax1.set_xlim([lim(min_x,-factor)   ,lim(max_x,factor)])
    ax1.set_ylim([lim(min_y,-factor)   ,lim(max_y,factor)])
    ax1.set_xlabel('Frequency [rad/s]', fontsize=12)
    ax1.set_ylabel('Normalized Amplitude', fontsize=12)
    #ax1.plot(p_d[i],y_d[0][i],'bo')
    ax1.set_title('2 dofs Duffing Oscillator with %i Harmonics and %i time samples' %(nH,n_points), fontsize=12)
    if legend:
        ax1.legend()
        legend = False
        
ani = FuncAnimation(fig, update, frames=np.arange(0, len(p_d) ,2 ), blit=True, interval=1)   

save = True
if save:
    Writer = animation.writers['imagemagick']
    writer = Writer(fps=60, metadata=dict(artist='Guilherme Jenovencio'), bitrate=-1)
    ani.save('2dof_Duffing_oscillator_1.gif', dpi=200, writer=writer)
# Out:
# <div id='92556a9e-2dc1-4dfb-a9e6-1bf29f6b92a2'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6fd5dcdfb381> in <module>()
#       2
#       3 fig, ax1 = plt.subplots(1)
# ----> 4 max_x = np.abs(p_d).max()
#       5 min_x = np.abs(p_d).min()
#       6 max_y = np.abs(y_d[dof_id]).max()
#
# NameError: name 'p_d' is not defined

# %%
#update(len(p_d)-1)
#fig.savefig('2dof_Duffing_oscillator_1.png')

# %%
# %%time
p = np.linspace(0.01,4,500)
Ru = lambda f : lambda u_ : R(u_,f)
#x0 = np.array([0],dtype=np.complex)
x0 = np.array([0]*n_dofs*nH,dtype=np.complex)
x_list = []
f_list = []
for f in p:
    opt_obj = optimize.root(Ru(f),x0=x0,tol=1.0E-12)
    x_opt = opt_obj.x
    #x0 = x_opt
    if opt_obj.success:
        x_list.append(x_opt)
        f_list.append(f)

# %%
plt.figure()
plt.plot(f_list, np.abs(x_list),'o')

# %%
plt.figure()
plt.plot(p_d.real)
plt.plot(p_d.imag)

# %%
val, vec = linalg.eig(K,M)

# %%
np.sqrt(1/val)

# %%
opt_obj = optimize.root(Ru(0.25),x0=x0,tol=1.0E-12)

# %%
opt_obj

# %%
fnl(opt_obj.x)

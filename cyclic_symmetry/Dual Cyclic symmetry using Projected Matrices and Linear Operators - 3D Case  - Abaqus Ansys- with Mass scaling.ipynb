# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

import scipy.sparse as sparse
import scipy.linalg as linalg
from scipy.sparse.linalg import LinearOperator
import numpy as np
import collections
import copy

import amfe
from amfe.utils.utils import OrderedSet
from amfe.cyclic.cyclic import SelectionOperator, apply_cyclic_symmetry, get_all_dofs, rotate_u, set_cyclic_modes_to_component
from amfe.cyclic.cyclic import create_voigt_rotation_matrix, assemble_cyclic_modes, cyclic_symmetry_modal_analysis, Cyclic_Symmetry_Modal_Analysis
from amfe.cyclic.cyclic import create_rotated_component, create_voigt_rotation_matrix, Cyclic_Component
from amfe.utils.utils import get_dofs
from amfe.linalg.arnoldi import arnoldi_iteration, inverse_arnoldi_iteration, general_inverse_arnoldi_iteration, generalized_arnoldi_iteration
from amfe.linalg.arnoldi import lanczos, is_eigvec, nullspace, LinearSys, power_iteration, ProjLinearSys, compute_modes, eigvec_error_vector, is_nullspace
from amfe.linalg.arnoldi import is_moore_pensore_inverse, ProjPrecondLinearSys
from amfe.contact import Cyclic_Contact
from amfe.units import convert
import pandas as pd
import logging 
from amfe.wrappers.ansys_wrapper import read_ansys_sparse_matrix

#msh_file = r'meshes\one_forth_disk_quad.msh'
#theta = np.pi/2.0 #

cases_dict = {}

cases_dict[1] =  {'msh_file' : r'meshes\simple_blade_disc.inp', 'msh_obj' : r'amfe_mesh_obj\simple_blade_disc.pkl',
                  'theta' : np.pi/4.0,
                  'scale' : 1000,
                  'tol_radius' : 1.0e-3,
                   'bc' : np.array([-50,50])}

cases_dict[2] = {'msh_file' : r'meshes\3D_simple_bladed_disk.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk.pkl',
                 'theta' : 2*np.pi/81.0,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}


cases_dict[3] = {'msh_file' : r'meshes\3D_simple_bladed_disk_course.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_course.pkl',
                 'theta' : 2*np.pi/81.0,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}


cases_dict[4] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}

cases_dict[5] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_V2.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_V2.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

cases_dict[6] = {'msh_file' : r'meshes\3d_simple_bladed_disk_24_sector.msh', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_gmsh.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}


cases_dict[7] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_v3.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_v3.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

cases_dict[8] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_quad.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_quad.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

#unpack case dict
case_id = 7
msh_file = cases_dict[case_id]['msh_file']
msh_obj = cases_dict[case_id]['msh_obj']
theta = cases_dict[case_id]['theta']
scale = cases_dict[case_id]['scale']
n_sector = int((2.0*np.pi)/abs(theta))
tol_radius = cases_dict[case_id]['tol_radius']
bc = cases_dict[case_id]['bc']

try:
    m = amfe.load_obj(msh_obj)
except:
    m = amfe.Mesh()
    if case_id==6:
        m.import_msh(msh_file,scale)
    else:
        m.import_inp(msh_file,scale)
    amfe.save_object(m,msh_obj)
# Out:
# Python was not able to load the fast fortran assembly routines.
#
# Python was not able to load the fast fortran material routines.

# %%
pltmsh = amfe.Plot3DMesh(m,boundaries=False,plot_nodes=False,alpha=0.5)
pltmsh.show()
pltmsh.ax.set_xlim(bc)
pltmsh.ax.set_ylim(bc)
pltmsh.ax.set_zlim(bc)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-200, 200)

# %%
m.get_phys_group_types()
# Out:
# {'BODY_1_1_ELSET',
#  'BODY_1_1_SOLID_ELSET',
#  'DIRICHLET_ELSET',
#  'LEFT_ELSET',
#  'RIGHT_ELSET'}

# %%
m.change_tag_in_eldf('phys_group','TOP_HIGH_ELSET','HIGH_ELSET')
m.change_tag_in_eldf('phys_group','TOP_LOW_ELSET','LOW_ELSET')
m.change_tag_in_eldf('phys_group','BODY_1_1_SOLID_ELSET','SOLID_1_1_SOLID_ELSET')
m.change_tag_in_eldf('phys_group','LEFT_ELSET','LOW_ELSET')
m.change_tag_in_eldf('phys_group','RIGHT_ELSET','HIGH_ELSET')
                     
dirsub = m.get_submesh('phys_group', 'DIRICHLET_ELSET')
cyclic_left = m.get_submesh('phys_group', 'LOW_ELSET')
cyclic_right = m.get_submesh('phys_group', 'HIGH_ELSET')
m.get_phys_group_types()
# Out:
# {'BODY_1_1_ELSET',
#  'DIRICHLET_ELSET',
#  'HIGH_ELSET',
#  'LOW_ELSET',
#  'SOLID_1_1_SOLID_ELSET'}

# %%
ax2 = amfe.plot3D_submesh(cyclic_left,alpha=1,plot_nodes=False,linewidth=0.1,color='blue')
ax2.set_xlim(bc)
ax2.set_ylim(bc )
ax2.set_zlim(bc)
amfe.plot3D_submesh(cyclic_right,alpha=1,plot_nodes=False,linewidth=0.1,color='orange',ax=ax2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
contact = Cyclic_Contact(cyclic_left,cyclic_right,sector_angle=theta, unit='rad',tol_radius = tol_radius)

# %%
ax3 = amfe.plot3D_submesh(contact.virtual_slave,alpha=1,plot_nodes=False,linewidth=0.1,color='grey')
#bc = np.array([0,300])
ax3.set_xlim(bc)
ax3.set_ylim(bc )
ax3.set_zlim(bc)
amfe.plot3D_submesh(cyclic_left,alpha=1,plot_nodes=False,linewidth=0.1,color='blue',ax=ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# creating a mechanical component
my_comp = amfe.MechanicalSystem()
my_comp.set_mesh_obj(m)
scaling_factor = 1.0E0
rho = 7.86E-9*scaling_factor # kg/mm3
E = 210.0E3 # MPa = N/mm2
my_material = amfe.KirchhoffMaterial(E=E, nu=0.3, rho=rho, plane_stress=False)
my_comp.set_domain('SOLID_1_1_SOLID_ELSET',my_material)

print('Number of nodes is equal to %i' %my_comp.mesh_class.no_of_nodes)
# Out:
# Preallocating the stiffness matrix
# Done preallocating stiffness matrix with 1431 elements and 1536 dofs.
# Time taken for preallocation: 0.03 seconds.
# Number of nodes is equal to 512

# %%
n_modes = 10
cyclic_obj = Cyclic_Symmetry_Modal_Analysis(my_comp,
                               dirsub,
                               cyclic_left,
                               cyclic_right,
                               sector_angle=theta,
                               unit='rad',
                               tol_radius = tol_radius, 
                               node_diam_range = (0,3),
                               n_modes=n_modes)

comp_list = cyclic_obj.comp_ND_list
s = cyclic_obj.selector_operator
# Out:
# xyz direction choosen for cyclic symmetry

# %%
from ipywidgets import interact
import mpl_toolkits.mplot3d as a3


def create_sector_list(my_comp,node_diam):
    sector_list = []
    for i in range(n_sector):
        sector_i = create_rotated_component(my_comp,s,sector_id=i, node_id=node_diam, theta=-theta, unit='rad', dimension=3)
        sector_list.append(sector_i)
    return sector_list

def plot_sector_list(sector_list, ax1):
    ax1.clear()
    plot_list = []
    reference = True
    for sector_i in sector_list:
        displacement = sector_i.u_output
        m_i = sector_i.mesh_class
        if reference:
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id, facecolor=0.8*np.array((1,1,1)))    
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, alpha=1,edgecolor='black',linewidth=0.1)   
            collections=[]
            reference = False
        else:
            
            
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id)
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, alpha=1,edgecolor='black',linewidth=0.1)   
            collections = pltmesh.ax.collections
        
        plot_list.append(pltmesh)
        
    return plot_list

node_id_selected = 0
sector_list_0 = create_sector_list(comp_list[0],node_id_selected)
sector_list_1 = create_sector_list(comp_list[1],node_id_selected)
sector_list_2 = create_sector_list(comp_list[2],node_id_selected)

fig0 = plt.figure(figsize=(8,8))
ax0 = fig0.add_subplot(1,1,1,projection='3d')
plt_list_0 = plot_sector_list(sector_list_0, ax0)
plt_list_1 = plot_sector_list(sector_list_1, ax0)
plt_list_2 = plot_sector_list(sector_list_2, ax0)
plt_list_primal = [plt_list_0,plt_list_1,plt_list_2]

ax0.set_xlim(bc)
ax0.set_ylim(bc)
ax0.set_zlim(bc)
@interact(factor=(-1.0,1.0,0.05),mode_id=(0,n_modes,1),node_id_selected=(0,3,1))
def plot2(factor=0.1,mode_id=0,node_id_selected=0):
    
    plt_list_0 = plt_list_primal[node_id_selected]
    collections = []
    for plot_obj in plt_list_0 :
        plot_obj.show(factor=10000*factor,plot_nodes=False,displacement_id=mode_id, collections=collections)
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(FloatSlider(value=0.1, description='factor', max=1.0, min=-1.0, step=0.05), IntSlider(va…

# %%
cyclic_comp = Cyclic_Component(my_comp,
                      dirsub,
                      cyclic_left,
                      cyclic_right,
                      sector_angle=theta,
                      unit='rad',
                      tol_radius = tol_radius)

#P_n_0 = cyclic_comp.build_complex_projection(0)
#P_n_1 = cyclic_comp.build_complex_projection(1)
#P_n_2 = cyclic_comp.build_complex_projection(2)
#P_n_3 = cyclic_comp.build_complex_projection(3)
#P_n_4 = cyclic_comp.build_complex_projection(4)
#P_n_5 = cyclic_comp.build_complex_projection(5)

max_number_of_node_diam = 12
P_n_list = []
for node_diam in range(max_number_of_node_diam+1):
    P_n_list.append(cyclic_comp.build_complex_projection(node_diam))

K_sector, M_sector = cyclic_comp.assemble_sector_operators()
s = cyclic_comp.s
# Out:
# xyz direction choosen for cyclic symmetry
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\scipy\sparse\compressed.py:746: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %%
P_n_list
# Out:
# [<1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>,
#  <1467x1467 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1977 stored elements in Compressed Sparse Row format>]

# %%
n_modes = 20
ndofs = cyclic_comp.ndofs
nc = cyclic_comp.nc
dimension = my_comp.mesh_class.no_of_dofs_per_node
no_of_dofs = my_comp.mesh_class.no_of_dofs
fill_perc = 0.2
drop_tol = 1.0E-6
#K_inv = sparse.linalg.inv(K_sector)
#K_pinv = P_n.dot(K_inv).dot(P_n)
#P_n_inv = sparse.csc_matrix(np.linalg.pinv(P_n.toarray()))
#P_n_list = [P_n_0,P_n_1,P_n_2,P_n_3]
res_dict = {}
for i in range(len(P_n_list)):
    
    P_n = P_n_list[i]

    Kp = P_n.conj().T.dot(K_sector.dot(P_n))
    scipy_K_inv = sparse.csc_matrix(np.linalg.pinv(Kp.toarray()))

    
    I = sparse.eye(ndofs)
    
    pre_obj1 = ProjPrecondLinearSys(K_sector,P_n, incomplete=True, fill_factor = int(fill_perc*no_of_dofs), drop_tol=drop_tol )
    pre_obj2 = ProjPrecondLinearSys(K_sector,P_n, incomplete=False )
    pre_obj3 = ProjPrecondLinearSys(K_sector,I, incomplete=True, fill_factor = int(fill_perc*no_of_dofs), drop_tol=drop_tol )
    pre_obj4 = ProjPrecondLinearSys(K_sector,I, incomplete=False )
    #pre_obj5 = ProjPrecondLinearSys(Kp,I, incomplete=False )
    
    #lu = sparse.linalg.splu(K_sector)
    #lui = sparse.linalg.spilu(K_sector)
    #lun = sparse.linalg.splu(Kp)

    precond0 = I
    precond1 = pre_obj1.getLinearOperator()
    precond2 = pre_obj2.getLinearOperator()
    precond3 = pre_obj3.getLinearOperator()
    precond4 = pre_obj4.getLinearOperator()
    #precond5 = pre_obj5.getLinearOperator()
    precond5 = scipy_K_inv

    list_precond = [precond0,
                   precond1,
                   precond2,
                   precond3,
                   precond4,
                   precond5]

    for j in range(len(list_precond)): #
        precond_j = list_precond[j]
        lo_obj = ProjLinearSys(K_sector,M_sector,P_n,precond_j)
        Dp_new = lo_obj.getLinearOperator()
        w2new, v2new = sparse.linalg.eigs(Dp_new, k=n_modes)
        new_id = np.argsort(w2new)[::-1]
        w2new = w2new[new_id]
        v2new = v2new[:,new_id]

        u_vnew = assemble_cyclic_modes(s,v2new,node_id=i,compute_left=False,dimension=dimension)
        comp_i = copy.deepcopy(my_comp)
        comp_i.u_output = []
        comp_i.u_output = list(u_vnew.T)
        local_dict = {}
        local_dict['comp']= comp_i
        local_dict['linearOp'] = lo_obj
        local_dict['TotalLienarOpCall'] = lo_obj.num_iters
        local_dict['AvgLienarOpCall'] = lo_obj.num_iters/lo_obj.solver_counter
        local_dict['eigenvalues'] = 1.0/(w2new.real)
        local_dict['omega'] = np.sqrt(scaling_factor*local_dict['eigenvalues'])
        local_dict['frequency'] = local_dict['omega']/(2.0*np.pi)
        local_dict['SolverCalls'] = lo_obj.solver_counter
        res_dict[i,j] =local_dict
# Out:
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in sqrt

# %%
res_dict
# Out:
# {(0, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2451f549da0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2451f549b00>,
#   'TotalLienarOpCall': 105640,
#   'AvgLienarOpCall': 1676.8253968253969,
#   'eigenvalues': array([1.63494224e+07, 5.80362871e+07, 4.08995855e+08, 1.66867361e+09,
#          2.00776505e+09, 2.48099060e+09, 3.24548335e+09, 9.07251886e+09,
#          1.03242999e+10, 1.15262517e+10, 1.22812661e+10, 1.49965744e+10,
#          1.97188631e+10, 2.27746419e+10, 4.10405929e+10, 4.88938842e+10,
#          4.98366252e+10, 5.37743240e+10, 5.96176941e+10, 6.55959399e+10]),
#   'omega': array([  4043.44189469,   7618.15509847,  20223.64594528,  40849.4016101 ,
#           44808.09138627,  49809.54321709,  56969.14381091,  95249.7708999 ,
#          101608.56201952, 107360.38246943, 110820.87397496, 122460.50135596,
#          140423.86955511, 150912.69639578, 202584.77954966, 221119.61524528,
#          223241.18170858, 231892.91490882, 244167.34864999, 256117.04333111]),
#   'frequency': array([  643.53376464,  1212.46704116,  3218.69321953,  6501.38418859,
#           7131.42923464,  7927.43501615,  9066.92084122, 15159.47186709,
#          16171.50490587, 17086.93556225, 17637.68989088, 19490.19412431,
#          22349.15296779, 24018.50160672, 32242.36906051, 35192.27978086,
#          35529.9375706 , 36906.90367573, 38860.44047929, 40762.29345623]),
#   'SolverCalls': 63},
#  (0, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2451f549c18>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245206edac8>,
#   'TotalLienarOpCall': 35781,
#   'AvgLienarOpCall': 567.952380952381,
#   'eigenvalues': array([1.63494224e+07, 5.80362871e+07, 4.08995855e+08, 1.66867361e+09,
#          2.00776505e+09, 2.48099060e+09, 3.24548335e+09, 9.07251886e+09,
#          1.03242999e+10, 1.15262517e+10, 1.22812661e+10, 1.49965744e+10,
#          1.97188631e+10, 2.27746419e+10, 4.10405929e+10, 4.88938842e+10,
#          4.98366252e+10, 5.37743240e+10, 5.96176941e+10, 6.55959399e+10]),
#   'omega': array([  4043.4418948 ,   7618.15509856,  20223.64594529,  40849.40161022,
#           44808.09138633,  49809.54321707,  56969.14381089,  95249.77089981,
#          101608.56201947, 107360.38246911, 110820.87397507, 122460.50135586,
#          140423.86955493, 150912.69639571, 202584.77955097, 221119.61524495,
#          223241.18170826, 231892.91490888, 244167.34865031, 256117.04333173]),
#   'frequency': array([  643.53376466,  1212.46704118,  3218.69321953,  6501.38418861,
#           7131.42923465,  7927.43501615,  9066.92084122, 15159.47186708,
#          16171.50490586, 17086.93556219, 17637.6898909 , 19490.1941243 ,
#          22349.15296776, 24018.5016067 , 32242.36906072, 35192.27978081,
#          35529.93757055, 36906.90367574, 38860.44047934, 40762.29345633]),
#   'SolverCalls': 63},
#  (0, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245206fbe80>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245064c8da0>,
#   'TotalLienarOpCall': 33165,
#   'AvgLienarOpCall': 526.4285714285714,
#   'eigenvalues': array([1.63494224e+07, 5.80362871e+07, 4.08995855e+08, 1.66867361e+09,
#          2.00776505e+09, 2.48099060e+09, 3.24548335e+09, 9.07251886e+09,
#          1.03242999e+10, 1.15262517e+10, 1.22812661e+10, 1.49965744e+10,
#          1.97188631e+10, 2.27746419e+10, 4.10405929e+10, 4.88938842e+10,
#          4.98366252e+10, 5.37743240e+10, 5.96176941e+10, 6.55959399e+10]),
#   'omega': array([  4043.44189477,   7618.15509848,  20223.64594528,  40849.40161012,
#           44808.09138625,  49809.54321704,  56969.14381094,  95249.77089992,
#          101608.56201948, 107360.38246898, 110820.87397521, 122460.50135587,
#          140423.86955511, 150912.69639579, 202584.77955027, 221119.61524511,
#          223241.18170843, 231892.9149089 , 244167.34865023, 256117.04333173]),
#   'frequency': array([  643.53376466,  1212.46704116,  3218.69321953,  6501.3841886 ,
#           7131.42923464,  7927.43501614,  9066.92084122, 15159.47186709,
#          16171.50490586, 17086.93556217, 17637.68989092, 19490.1941243 ,
#          22349.15296779, 24018.50160672, 32242.36906061, 35192.27978084,
#          35529.93757057, 36906.90367574, 38860.44047933, 40762.29345633]),
#   'SolverCalls': 63},
#  (0, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2450658fb38>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245065630b8>,
#   'TotalLienarOpCall': 35802,
#   'AvgLienarOpCall': 568.2857142857143,
#   'eigenvalues': array([ 1.63494359e+07,  5.80348841e+07,  4.08995985e+08,  1.66867255e+09,
#           2.00776596e+09,  2.48099083e+09,  3.24548313e+09,  9.07251880e+09,
#           1.03242999e+10,  1.15262518e+10,  1.22812666e+10,  1.49965744e+10,
#           1.97188621e+10,  2.27746419e+10,  4.10405928e+10,  4.88938828e+10,
#           4.98366263e+10,  5.37743240e+10,  5.96176943e+10, -2.28680531e+08]),
#   'omega': array([  4043.44356529,   7618.06301607,  20223.6491498 ,  40849.38856227,
#           44808.10150642,  49809.5456143 ,  56969.14195314,  95249.77061519,
#          101608.56207028, 107360.38305153, 110820.87618299, 122460.50122408,
#          140423.86573086, 150912.69616779, 202584.77918662, 221119.61202623,
#          223241.18424139, 231892.91500814, 244167.3489491 ,             nan]),
#   'frequency': array([  643.53403053,  1212.45238579,  3218.69372955,  6501.38211197,
#           7131.43084531,  7927.43539768,  9066.92054555, 15159.47182178,
#          16171.50491395, 17086.93565489, 17637.6902423 , 19490.19410332,
#          22349.15235914, 24018.50157043, 32242.36900273, 35192.27926854,
#          35529.93797371, 36906.90369153, 38860.44052689,            nan]),
#   'SolverCalls': 63},
#  (0, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2450658f470>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245065ee390>,
#   'TotalLienarOpCall': 33161,
#   'AvgLienarOpCall': 526.3650793650794,
#   'eigenvalues': array([1.63494234e+07, 5.80362868e+07, 4.08995855e+08, 1.66867359e+09,
#          2.00776504e+09, 2.48099060e+09, 3.24548334e+09, 9.07251882e+09,
#          1.03242999e+10, 1.15262519e+10, 1.22812661e+10, 1.49965744e+10,
#          1.97188633e+10, 2.27746422e+10, 4.10405930e+10, 4.88938843e+10,
#          4.98366254e+10, 5.37743240e+10, 5.96176938e+10, 6.55959398e+10]),
#   'omega': array([  4043.44201782,   7618.15507591,  20223.64593283,  40849.4013116 ,
#           44808.09128515,  49809.54321558,  56969.14379244,  95249.77070353,
#          101608.56201671, 107360.38310469, 110820.87398924, 122460.50138692,
#          140423.87007634, 150912.69729765, 202584.77966362, 221119.61534467,
#          223241.18217054, 231892.91492306, 244167.34802257, 256117.04320128]),
#   'frequency': array([  643.53378424,  1212.46703757,  3218.69321755,  6501.38414109,
#           7131.42921854,  7927.43501591,  9066.92083828, 15159.47183584,
#          16171.50490542, 17086.93566335, 17637.68989315, 19490.19412924,
#          22349.15305074, 24018.50175025, 32242.36907865, 35192.27979668,
#          35529.93764412, 36906.90367799, 38860.44037943, 40762.29343556]),
#   'SolverCalls': 63},
#  (0, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2450661a780>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24506676668>,
#   'TotalLienarOpCall': 14722,
#   'AvgLienarOpCall': 283.11538461538464,
#   'eigenvalues': array([6.15982692e-04, 5.36202434e+07, 4.10592558e+08, 1.76137490e+09,
#          2.22037732e+09, 2.49242971e+09, 3.21569897e+09, 9.00173905e+09,
#          1.04457367e+10, 1.13512692e+10, 1.21943528e+10, 1.50628464e+10,
#          2.01181482e+10, 2.33000965e+10, 4.13642803e+10, 4.67297863e+10,
#          4.83620590e+10, 5.48750825e+10, 5.82185213e+10, 6.38831645e+10]),
#   'omega': array([2.48189986e-02, 7.32258447e+03, 2.02630836e+04, 4.19687372e+04,
#          4.71208799e+04, 4.99242397e+04, 5.67071334e+04, 9.48774950e+04,
#          1.02204387e+05, 1.06542335e+05, 1.10428044e+05, 1.22730788e+05,
#          1.41838458e+05, 1.52643691e+05, 2.03382104e+05, 2.16170734e+05,
#          2.19913753e+05, 2.34254312e+05, 2.41285145e+05, 2.52751191e+05]),
#   'frequency': array([3.95006631e-03, 1.16542552e+03, 3.22496992e+03, 6.67953198e+03,
#          7.49952095e+03, 7.94568952e+03, 9.02522058e+03, 1.51002223e+04,
#          1.62663333e+04, 1.69567393e+04, 1.75751690e+04, 1.95332117e+04,
#          2.25742917e+04, 2.42939980e+04, 3.23692672e+04, 3.44046409e+04,
#          3.50003609e+04, 3.72827316e+04, 3.84017236e+04, 4.02266014e+04]),
#   'SolverCalls': 52},
#  (1, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2450675b710>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24506722f60>,
#   'TotalLienarOpCall': 90611,
#   'AvgLienarOpCall': 1438.2698412698412,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.0559763 ,  18242.25127565,  20263.54967073,  42251.7504238 ,
#           50239.57038885,  53653.26520765,  57639.17844385,  96753.02290469,
#          101564.07491329, 106924.41192871, 110764.56836359, 122261.85589028,
#          142330.88452958, 150944.0698456 , 202214.88029497, 221105.29926237,
#          226817.92595052, 232405.80417418, 237655.42602533, 256134.84752938]),
#   'frequency': array([ 1158.33858473,  2903.34446364,  3225.04409468,  6724.57493423,
#           7995.8759662 ,  8539.18237082,  9173.56016509, 15398.72185437,
#          16164.42456301, 17017.54869565, 17628.72857451, 19458.57871653,
#          22652.66382752, 24023.49484634, 32183.49776568, 35190.00132142,
#          36099.19409688, 36988.53253757, 37824.03580454, 40765.12708239]),
#   'SolverCalls': 63},
#  (1, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538e1f9e8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2450675b7b8>,
#   'TotalLienarOpCall': 22360,
#   'AvgLienarOpCall': 354.92063492063494,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.05597629,  18242.25127566,  20263.54967072,  42251.75042382,
#           50239.57038884,  53653.26520766,  57639.17844387,  96753.02290468,
#          101564.0749133 , 106924.41192873, 110764.56836373, 122261.85589031,
#          142330.88452945, 150944.06984561, 202214.88029509, 221105.29926248,
#          226817.92595046, 232405.80417424, 237655.4260253 , 256134.8475296 ]),
#   'frequency': array([ 1158.33858473,  2903.34446365,  3225.04409468,  6724.57493424,
#           7995.8759662 ,  8539.18237082,  9173.5601651 , 15398.72185436,
#          16164.42456301, 17017.54869565, 17628.72857453, 19458.57871653,
#          22652.6638275 , 24023.49484634, 32183.4977657 , 35190.00132144,
#          36099.19409687, 36988.53253758, 37824.03580454, 40765.12708242]),
#   'SolverCalls': 63},
#  (1, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538ea5780>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24538e79240>,
#   'TotalLienarOpCall': 18915,
#   'AvgLienarOpCall': 300.23809523809524,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.05597631,  18242.25127566,  20263.54967073,  42251.7504238 ,
#           50239.57038885,  53653.26520765,  57639.17844385,  96753.02290469,
#          101564.0749133 , 106924.4119287 , 110764.5683636 , 122261.85589027,
#          142330.88452951, 150944.06984563, 202214.88029496, 221105.29926246,
#          226817.9259505 , 232405.80417426, 237655.42602563, 256134.84752948]),
#   'frequency': array([ 1158.33858473,  2903.34446365,  3225.04409468,  6724.57493423,
#           7995.8759662 ,  8539.18237082,  9173.56016509, 15398.72185437,
#          16164.42456301, 17017.54869565, 17628.72857451, 19458.57871653,
#          22652.66382751, 24023.49484634, 32183.49776568, 35190.00132143,
#          36099.19409687, 36988.53253758, 37824.03580459, 40765.12708241]),
#   'SolverCalls': 63},
#  (1, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538ea55f8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24538efc518>,
#   'TotalLienarOpCall': 22341,
#   'AvgLienarOpCall': 354.6190476190476,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.0559763 ,  18242.25127566,  20263.54967073,  42251.7504238 ,
#           50239.57038886,  53653.26520766,  57639.17844384,  96753.02290469,
#          101564.07491333, 106924.41192872, 110764.56836359, 122261.85589031,
#          142330.88452946, 150944.06984562, 202214.88029502, 221105.2992625 ,
#          226817.9259506 , 232405.80417425, 237655.42602555, 256134.84752915]),
#   'frequency': array([ 1158.33858473,  2903.34446364,  3225.04409468,  6724.57493423,
#           7995.8759662 ,  8539.18237082,  9173.56016509, 15398.72185437,
#          16164.42456301, 17017.54869565, 17628.72857451, 19458.57871653,
#          22652.66382751, 24023.49484634, 32183.49776569, 35190.00132144,
#          36099.19409689, 36988.53253758, 37824.03580458, 40765.12708235]),
#   'SolverCalls': 63},
#  (1, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538f288d0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24538f807f0>,
#   'TotalLienarOpCall': 4320,
#   'AvgLienarOpCall': 68.57142857142857,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.0559763 ,  18242.25127565,  20263.54967072,  42251.7504238 ,
#           50239.57038885,  53653.26520765,  57639.17844385,  96753.02290468,
#          101564.07491332, 106924.41192872, 110764.56836362, 122261.85589024,
#          142330.88452948, 150944.06984562, 202214.88029501, 221105.29926248,
#          226817.92595057, 232405.80417427, 237655.42602553, 256134.84752956]),
#   'frequency': array([ 1158.33858473,  2903.34446364,  3225.04409468,  6724.57493423,
#           7995.8759662 ,  8539.18237082,  9173.56016509, 15398.72185436,
#          16164.42456301, 17017.54869565, 17628.72857451, 19458.57871652,
#          22652.66382751, 24023.49484634, 32183.49776569, 35190.00132144,
#          36099.19409689, 36988.53253758, 37824.03580457, 40765.12708242]),
#   'SolverCalls': 63},
#  (1, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538fabba8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539004ac8>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([5.29700988e+07, 3.32779732e+08, 4.10611445e+08, 1.78521041e+09,
#          2.52401443e+09, 2.87867287e+09, 3.32227489e+09, 9.36114744e+09,
#          1.03152613e+10, 1.14328299e+10, 1.22687896e+10, 1.49479614e+10,
#          2.02580807e+10, 2.27841122e+10, 4.08908578e+10, 4.88875534e+10,
#          5.14463715e+10, 5.40124578e+10, 5.64801015e+10, 6.56050601e+10]),
#   'omega': array([  7278.05597629,  18242.25127566,  20263.54967072,  42251.75042378,
#           50239.57038882,  53653.26520764,  57639.1784438 ,  96753.02290466,
#          101564.07491327, 106924.4119287 , 110764.5683636 , 122261.85589017,
#          142330.8845293 , 150944.06984549, 202214.88029476, 221105.29926228,
#          226817.92595029, 232405.80417395, 237655.42602506, 256134.84752898]),
#   'frequency': array([ 1158.33858473,  2903.34446365,  3225.04409468,  6724.57493423,
#           7995.87596619,  8539.18237082,  9173.56016509, 15398.72185436,
#          16164.424563  , 17017.54869565, 17628.72857451, 19458.57871651,
#          22652.66382748, 24023.49484632, 32183.49776565, 35190.0013214 ,
#          36099.19409684, 36988.53253753, 37824.0358045 , 40765.12708233]),
#   'SolverCalls': 63},
#  (2, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245390beda0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245390be400>,
#   'TotalLienarOpCall': 89574,
#   'AvgLienarOpCall': 1421.8095238095239,
#   'eigenvalues': array([5.23202549e+07, 4.61384207e+08, 9.69754789e+08, 1.93536956e+09,
#          3.04003744e+09, 3.46709840e+09, 5.37386092e+09, 9.91591349e+09,
#          1.07362361e+10, 1.12716322e+10, 1.24913696e+10, 1.49643275e+10,
#          2.16044664e+10, 2.28566242e+10, 4.02748832e+10, 4.77219422e+10,
#          5.16708789e+10, 5.51132293e+10, 5.69871353e+10, 6.48010165e+10]),
#   'omega': array([  7233.27414805,  21479.8558309 ,  31140.88613542,  43992.83528472,
#           55136.53455744,  58882.07197983,  73306.62264275,  99578.67989965,
#          103615.81030536, 106167.94356261, 111764.79594035, 122328.76804218,
#          146984.57868878, 151184.07399227, 200686.03137599, 218453.52422875,
#          227312.29372353, 234762.06960924, 238719.78414484, 254560.43785338]),
#   'frequency': array([ 1151.2113354 ,  3418.62523239,  4956.22596071,  7001.67719619,
#           8775.25201977,  9371.37281508, 11667.11135497, 15848.4391326 ,
#          16490.96839257, 16897.15301589, 17787.91973756, 19469.22811626,
#          23393.3222566 , 24061.69269264, 31940.17390298, 34767.95821685,
#          36177.87517166, 37363.54382879, 37993.43366048, 40514.552     ]),
#   'SolverCalls': 63},
#  (2, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245390be4a8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539092e80>,
#   'TotalLienarOpCall': 22684,
#   'AvgLienarOpCall': 360.06349206349205,
#   'eigenvalues': array([5.23202571e+07, 4.61384208e+08, 9.69754789e+08, 1.93536956e+09,
#          3.04003744e+09, 3.46709842e+09, 5.37386092e+09, 9.91591347e+09,
#          1.07362361e+10, 1.12716322e+10, 1.24913696e+10, 1.49643275e+10,
#          2.16044664e+10, 2.28566242e+10, 4.02748832e+10, 4.77219423e+10,
#          5.16708789e+10, 5.51132293e+10, 5.69871354e+10, 6.48010165e+10]),
#   'omega': array([  7233.27430054,  21479.85585656,  31140.88613392,  43992.8352934 ,
#           55136.53453467,  58882.07213105,  73306.62264388,  99578.67979521,
#          103615.81029929, 106167.9435621 , 111764.79568862, 122328.76793706,
#          146984.57877744, 151184.07393327, 200686.03131313, 218453.52437322,
#          227312.29377878, 234762.06962364, 238719.78417533, 254560.43791042]),
#   'frequency': array([ 1151.21135967,  3418.62523647,  4956.22596048,  7001.67719757,
#           8775.25201615,  9371.37283915, 11667.11135515, 15848.43911597,
#          16490.9683916 , 16897.15301581, 17787.9196975 , 19469.22809952,
#          23393.32227071, 24061.69268325, 31940.17389298, 34767.95823984,
#          36177.87518045, 37363.54383109, 37993.43366533, 40514.55200908]),
#   'SolverCalls': 63},
#  (2, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24539cb2b00>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539030ba8>,
#   'TotalLienarOpCall': 19122,
#   'AvgLienarOpCall': 303.5238095238095,
#   'eigenvalues': array([5.23202549e+07, 4.61384207e+08, 9.69754789e+08, 1.93536956e+09,
#          3.04003744e+09, 3.46709840e+09, 5.37386092e+09, 9.91591349e+09,
#          1.07362361e+10, 1.12716322e+10, 1.24913696e+10, 1.49643275e+10,
#          2.16044664e+10, 2.28566242e+10, 4.02748832e+10, 4.77219422e+10,
#          5.16708789e+10, 5.51132293e+10, 5.69871353e+10, 6.48010165e+10]),
#   'omega': array([  7233.27414805,  21479.8558309 ,  31140.88613542,  43992.83528472,
#           55136.53455744,  58882.07197983,  73306.62264275,  99578.6798997 ,
#          103615.81030536, 106167.94356259, 111764.79594036, 122328.76804216,
#          146984.57868884, 151184.07399225, 200686.03137598, 218453.52422871,
#          227312.29372362, 234762.06960926, 238719.78414494, 254560.43785327]),
#   'frequency': array([ 1151.2113354 ,  3418.62523239,  4956.22596071,  7001.67719619,
#           8775.25201977,  9371.37281508, 11667.11135497, 15848.4391326 ,
#          16490.96839257, 16897.15301589, 17787.91973756, 19469.22811625,
#          23393.32225661, 24061.69269264, 31940.17390298, 34767.95821684,
#          36177.87517167, 37363.5438288 , 37993.4336605 , 40514.55199999]),
#   'SolverCalls': 63},
#  (2, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24539c83898>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539114da0>,
#   'TotalLienarOpCall': 21275,
#   'AvgLienarOpCall': 409.13461538461536,
#   'eigenvalues': array([ 5.23232304e+07,  4.61384713e+08,  9.69754707e+08,  1.93536947e+09,
#           3.04003784e+09,  3.46709861e+09,  5.37386092e+09,  9.91591296e+09,
#           1.07362363e+10,  1.12716320e+10,  1.24913703e+10,  1.49643284e+10,
#           2.16044665e+10,  2.28566250e+10,  4.02748812e+10,  4.77219432e+10,
#           5.16708872e+10,  5.51132296e+10,  5.69871355e+10, -2.60348747e+08]),
#   'omega': array([  7233.47982806,  21479.86761728,  31140.88482152,  43992.83427363,
#           55136.53812253,  58882.07376334,  73306.62261738,  99578.67722441,
#          103615.81100731, 106167.94234103, 111764.79885747, 122328.77192406,
#          146984.5789934 , 151184.0766151 , 200686.02638445, 218453.5264883 ,
#          227312.31200671, 234762.07023536, 238719.78451709,             nan]),
#   'frequency': array([ 1151.24407039,  3418.62710825,  4956.2257516 ,  7001.67703527,
#           8775.25258718,  9371.37309894, 11667.11135093, 15848.43870682,
#          16490.96850429, 16897.15282147, 17787.92020184, 19469.22873408,
#          23393.32230508, 24061.69311008, 31940.17310856, 34767.95857647,
#          36177.87808151, 37363.54392844, 37993.43371973,            nan]),
#   'SolverCalls': 52},
#  (2, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453a9a6c18>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453aa20080>,
#   'TotalLienarOpCall': 18314,
#   'AvgLienarOpCall': 352.1923076923077,
#   'eigenvalues': array([5.23239308e+07, 3.97558322e+08, 4.61357127e+08, 9.69756002e+08,
#          1.93536950e+09, 3.04003734e+09, 3.46709837e+09, 5.37386093e+09,
#          9.91591509e+09, 1.07362361e+10, 1.12716340e+10, 1.24913667e+10,
#          1.49643262e+10, 2.16044663e+10, 2.28566234e+10, 4.02748860e+10,
#          4.77219402e+10, 5.16708569e+10, 5.51132292e+10, 5.69871355e+10]),
#   'omega': array([  7233.52823975,  19938.86461234,  21479.22547931,  31140.905605  ,
#           43992.83468953,  55136.533625  ,  58882.0717027 ,  73306.62271779,
#           99578.68791108, 103615.81021383, 106167.95187275, 111764.78313398,
#          122328.76296353, 146984.57829723, 151184.07131109, 200686.03846768,
#          218453.51955661, 227312.24528981, 234762.06934161, 238719.7844552 ]),
#   'frequency': array([ 1151.25177535,  3173.36886269,  3418.52490882,  4956.22905939,
#           7001.67710146,  8775.25187137,  9371.37277098, 11667.11136691,
#          15848.44040765, 16490.968378  , 16897.15433849, 17787.91769937,
#          19469.22730796, 23393.32219428, 24061.69226592, 31940.17503166,
#          34767.95747326, 36177.86746319, 37363.5437862 , 37993.43370988]),
#   'SolverCalls': 52},
#  (2, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453aad3780>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453aa89630>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([5.23202549e+07, 4.61384207e+08, 9.69754789e+08, 1.93536956e+09,
#          3.04003744e+09, 3.46709840e+09, 5.37386092e+09, 9.91591349e+09,
#          1.07362361e+10, 1.12716322e+10, 1.24913696e+10, 1.49643275e+10,
#          2.16044664e+10, 2.28566242e+10, 4.02748832e+10, 4.77219422e+10,
#          5.16708789e+10, 5.51132293e+10, 5.69871353e+10, 6.48010165e+10]),
#   'omega': array([  7233.27414805,  21479.85583089,  31140.8861354 ,  43992.83528471,
#           55136.53455739,  58882.0719798 ,  73306.62264271,  99578.67989957,
#          103615.81030531, 106167.94356258, 111764.79594038, 122328.7680421 ,
#          146984.57868866, 151184.07399221, 200686.03137591, 218453.52422851,
#          227312.29372327, 234762.06960901, 238719.7841447 , 254560.43785322]),
#   'frequency': array([ 1151.2113354 ,  3418.62523239,  4956.22596071,  7001.67719619,
#           8775.25201977,  9371.37281508, 11667.11135496, 15848.43913258,
#          16490.96839256, 16897.15301589, 17787.91973757, 19469.22811624,
#          23393.32225658, 24061.69269263, 31940.17390297, 34767.95821681,
#          36177.87517162, 37363.54382876, 37993.43366046, 40514.55199998]),
#   'SolverCalls': 63},
#  (3, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453ab30fd0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453ab30da0>,
#   'TotalLienarOpCall': 101482,
#   'AvgLienarOpCall': 1610.8253968253969,
#   'eigenvalues': array([7.12196641e+07, 6.90074522e+08, 1.26170892e+09, 2.05798537e+09,
#          3.73220734e+09, 4.73966837e+09, 7.71245873e+09, 9.92550419e+09,
#          1.15320646e+10, 1.24350730e+10, 1.43113521e+10, 1.54727972e+10,
#          2.25557063e+10, 2.38627361e+10, 3.86608466e+10, 4.48432194e+10,
#          4.91191811e+10, 5.68490171e+10, 6.32179555e+10, 6.61438673e+10]),
#   'omega': array([  8439.1743742 ,  26269.26954042,  35520.54216619,  45365.02367864,
#           61091.79440953,  68845.24942203,  87820.60536051,  99626.82465596,
#          107387.45065402, 111512.65853111, 119630.06356872, 124389.69878335,
#          150185.57299853, 154475.6811438 , 196623.61661239, 211762.17654997,
#          221628.47532913, 238430.31926224, 251431.81080635, 257184.50043419]),
#   'frequency': array([ 1343.13631727,  4180.88409877,  5653.26986705,  7220.06776194,
#           9723.06106263, 10957.06175391, 13977.08344845, 15856.10160855,
#          17091.24359763, 17747.79082254, 19039.71595936, 19797.23543108,
#          23902.7763238 , 24585.56824152, 31293.62051247, 33702.99715783,
#          35273.26737855, 37947.36389356, 40016.61554038, 40932.18453072]),
#   'SolverCalls': 63},
#  (3, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453abdeb00>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453aa899e8>,
#   'TotalLienarOpCall': 23129,
#   'AvgLienarOpCall': 367.12698412698415,
#   'eigenvalues': array([7.12196640e+07, 6.90074522e+08, 1.26170892e+09, 2.05798537e+09,
#          3.73220734e+09, 4.73966837e+09, 7.71245873e+09, 9.92550419e+09,
#          1.15320646e+10, 1.24350730e+10, 1.43113521e+10, 1.54727972e+10,
#          2.25557063e+10, 2.38627361e+10, 3.86608466e+10, 4.48432194e+10,
#          4.91191811e+10, 5.68490171e+10, 6.32179555e+10, 6.61438673e+10]),
#   'omega': array([  8439.17436464,  26269.26954058,  35520.54216863,  45365.02368274,
#           61091.79440606,  68845.24942421,  87820.60536124,  99626.82465796,
#          107387.45065283, 111512.65853157, 119630.06356239, 124389.69877612,
#          150185.57298656, 154475.68114094, 196623.61661879, 211762.17655446,
#          221628.47532386, 238430.31926318, 251431.81081622, 257184.50044084]),
#   'frequency': array([ 1343.13631575,  4180.8840988 ,  5653.26986744,  7220.06776259,
#           9723.06106208, 10957.06175426, 13977.08344856, 15856.10160886,
#          17091.24359744, 17747.79082262, 19039.71595835, 19797.23542993,
#          23902.7763219 , 24585.56824107, 31293.62051349, 33702.99715854,
#          35273.26737771, 37947.36389371, 40016.61554195, 40932.18453178]),
#   'SolverCalls': 63},
#  (3, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453ab30f60>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453abaf898>,
#   'TotalLienarOpCall': 4795,
#   'AvgLienarOpCall': 76.11111111111111,
#   'eigenvalues': array([7.12196640e+07, 6.90074522e+08, 1.26170892e+09, 2.05798537e+09,
#          3.73220734e+09, 4.73966837e+09, 7.71245873e+09, 9.92550419e+09,
#          1.15320646e+10, 1.24350730e+10, 1.43113521e+10, 1.54727972e+10,
#          2.25557063e+10, 2.38627361e+10, 3.86608466e+10, 4.48432194e+10,
#          4.91191811e+10, 5.68490171e+10, 6.32179555e+10, 6.61438673e+10]),
#   'omega': array([  8439.17436463,  26269.26954058,  35520.54216864,  45365.02368273,
#           61091.79440606,  68845.24942421,  87820.60536124,  99626.82465794,
#          107387.45065281, 111512.65853159, 119630.06356237, 124389.69877607,
#          150185.57298658, 154475.68114088, 196623.61661884, 211762.17655449,
#          221628.47532384, 238430.31926314, 251431.81081624, 257184.50044088]),
#   'frequency': array([ 1343.13631575,  4180.8840988 ,  5653.26986744,  7220.06776259,
#           9723.06106208, 10957.06175426, 13977.08344856, 15856.10160886,
#          17091.24359743, 17747.79082262, 19039.71595835, 19797.23542992,
#          23902.7763219 , 24585.56824106, 31293.62051349, 33702.99715855,
#          35273.26737771, 37947.36389371, 40016.61554195, 40932.18453179]),
#   'SolverCalls': 63},
#  (3, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2453b73ea58>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453abde390>,
#   'TotalLienarOpCall': 8682,
#   'AvgLienarOpCall': 137.8095238095238,
#   'eigenvalues': array([7.12196640e+07, 6.90074522e+08, 1.26170892e+09, 2.05798537e+09,
#          3.73220734e+09, 4.73966837e+09, 7.71245873e+09, 9.92550419e+09,
#          1.15320646e+10, 1.24350730e+10, 1.43113521e+10, 1.54727972e+10,
#          2.25557063e+10, 2.38627361e+10, 3.86608466e+10, 4.48432194e+10,
#          4.91191811e+10, 5.68490171e+10, 6.32179555e+10, 6.61438673e+10]),
#   'omega': array([  8439.17436464,  26269.26954058,  35520.54216863,  45365.02368273,
#           61091.79440606,  68845.2494242 ,  87820.60536124,  99626.82465794,
#          107387.45065281, 111512.65853158, 119630.06356247, 124389.69877599,
#          150185.5729866 , 154475.68114089, 196623.61661859, 211762.17655431,
#          221628.47532406, 238430.31926316, 251431.81081622, 257184.50044077]),
#   'frequency': array([ 1343.13631575,  4180.8840988 ,  5653.26986744,  7220.06776259,
#           9723.06106208, 10957.06175426, 13977.08344856, 15856.10160886,
#          17091.24359743, 17747.79082262, 19039.71595836, 19797.23542991,
#          23902.77632191, 24585.56824106, 31293.62051345, 33702.99715852,
#          35273.26737774, 37947.36389371, 40016.61554195, 40932.18453177]),
#   'SolverCalls': 63},
#  (3, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24578f4b748>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453cf61630>,
#   'TotalLienarOpCall': 18556,
#   'AvgLienarOpCall': 356.84615384615387,
#   'eigenvalues': array([ 7.12196643e+07,  6.90074522e+08,  1.26170892e+09,  2.05798537e+09,
#           3.73220734e+09,  4.73966837e+09,  7.71245873e+09,  9.92550419e+09,
#           1.15320646e+10,  1.24350730e+10,  1.43113521e+10,  1.54727972e+10,
#           2.25557063e+10,  2.38627361e+10,  3.86608466e+10,  4.48432194e+10,
#           4.91191811e+10,  5.68490171e+10,  6.32179555e+10, -5.61371886e+08]),
#   'omega': array([  8439.17438784,  26269.26953996,  35520.54216854,  45365.0236835 ,
#           61091.7944131 ,  68845.24942416,  87820.60536138,  99626.82465893,
#          107387.45065312, 111512.65853143, 119630.06356313, 124389.69877677,
#          150185.57298687, 154475.68114076, 196623.61661918, 211762.17655462,
#          221628.47532448, 238430.31926315, 251431.81081673,             nan]),
#   'frequency': array([ 1343.13631944,  4180.8840987 ,  5653.26986743,  7220.06776271,
#           9723.0610632 , 10957.06175425, 13977.08344859, 15856.10160902,
#          17091.24359748, 17747.79082259, 19039.71595847, 19797.23543003,
#          23902.77632195, 24585.56824104, 31293.62051355, 33702.99715857,
#          35273.26737781, 37947.36389371, 40016.61554203,            nan]),
#   'SolverCalls': 52},
#  (3, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24578f4b4e0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24578f4b550>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([7.12196640e+07, 6.90074522e+08, 1.26170892e+09, 2.05798537e+09,
#          3.73220734e+09, 4.73966837e+09, 7.71245873e+09, 9.92550419e+09,
#          1.15320646e+10, 1.24350730e+10, 1.43113521e+10, 1.54727972e+10,
#          2.25557063e+10, 2.38627361e+10, 3.86608466e+10, 4.48432194e+10,
#          4.91191811e+10, 5.68490171e+10, 6.32179555e+10, 6.61438673e+10]),
#   'omega': array([  8439.17436462,  26269.26954058,  35520.54216862,  45365.02368272,
#           61091.79440616,  68845.24942423,  87820.60536126,  99626.82465795,
#          107387.45065282, 111512.6585316 , 119630.06356239, 124389.69877607,
#          150185.5729866 , 154475.6811409 , 196623.61661878, 211762.17655422,
#          221628.47532382, 238430.31926316, 251431.81081629, 257184.50044078]),
#   'frequency': array([ 1343.13631574,  4180.8840988 ,  5653.26986744,  7220.06776259,
#           9723.06106209, 10957.06175426, 13977.08344857, 15856.10160886,
#          17091.24359743, 17747.79082262, 19039.71595835, 19797.23542992,
#          23902.77632191, 24585.56824106, 31293.62051348, 33702.9971585 ,
#          35273.26737771, 37947.36389371, 40016.61554196, 40932.18453177]),
#   'SolverCalls': 63},
#  (4, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2457905bb00>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2457905b390>,
#   'TotalLienarOpCall': 86394,
#   'AvgLienarOpCall': 1371.3333333333333,
#   'eigenvalues': array([1.36796235e+08, 1.23183075e+09, 1.33032212e+09, 2.10407628e+09,
#          4.12123712e+09, 7.41945781e+09, 8.16768383e+09, 1.02599558e+10,
#          1.19506660e+10, 1.40415307e+10, 1.62661383e+10, 2.09219262e+10,
#          2.26117946e+10, 2.60927077e+10, 3.54356450e+10, 4.21099536e+10,
#          4.78102342e+10, 5.94254226e+10, 6.22967865e+10, 7.51112286e+10]),
#   'omega': array([ 11695.99226504,  35097.44648044,  36473.5811395 ,  45870.21120578,
#           64196.86226684,  86136.27466757,  90375.23902755, 101291.44013922,
#          109319.10181926, 118496.96507524, 127538.77175021, 144644.13640415,
#          150372.18702128, 161532.37351106, 188243.5788905 , 205207.09939132,
#          218655.51482537, 243773.30164189, 249593.24216928, 274064.27830631]),
#   'frequency': array([ 1861.47498335,  5585.93209726,  5804.95073061,  7300.47085407,
#          10217.24796076, 13709.01389286, 14383.66602435, 16121.03339105,
#          17398.6754289 , 18859.37773311, 20298.42595991, 23020.82929798,
#          23932.47686798, 25708.67571365, 29959.89608573, 32659.72422568,
#          34800.10601876, 38797.72595014, 39723.99825357, 43618.68461736]),
#   'SolverCalls': 63},
#  (4, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2457905b3c8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2453c2ac080>,
#   'TotalLienarOpCall': 8945,
#   'AvgLienarOpCall': 141.984126984127,
#   'eigenvalues': array([1.36796235e+08, 1.23183075e+09, 1.33032212e+09, 2.10407628e+09,
#          4.12123712e+09, 7.41945781e+09, 8.16768383e+09, 1.02599558e+10,
#          1.19506660e+10, 1.40415307e+10, 1.62661383e+10, 2.09219262e+10,
#          2.26117946e+10, 2.60927077e+10, 3.54356450e+10, 4.21099536e+10,
#          4.78102342e+10, 5.94254226e+10, 6.22967865e+10, 7.51112286e+10]),
#   'omega': array([ 11695.99226504,  35097.44648043,  36473.5811395 ,  45870.21120578,
#           64196.86226685,  86136.27466757,  90375.23902752, 101291.44013924,
#          109319.10181929, 118496.96507519, 127538.77175016, 144644.13640408,
#          150372.18702128, 161532.37351111, 188243.57889059, 205207.09939154,
#          218655.51482546, 243773.30164189, 249593.24216949, 274064.27830646]),
#   'frequency': array([ 1861.47498335,  5585.93209726,  5804.95073061,  7300.47085407,
#          10217.24796076, 13709.01389287, 14383.66602434, 16121.03339106,
#          17398.67542891, 18859.3777331 , 20298.42595991, 23020.82929797,
#          23932.47686798, 25708.67571366, 29959.89608575, 32659.72422571,
#          34800.10601877, 38797.72595014, 39723.99825361, 43618.68461739]),
#   'SolverCalls': 63},
#  (4, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2451de687f0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24503ffd4e0>,
#   'TotalLienarOpCall': 19558,
#   'AvgLienarOpCall': 310.44444444444446,
#   'eigenvalues': array([7.04064669e+07, 1.21479038e+09, 1.31242754e+09, 2.16199107e+09,
#          4.10105768e+09, 7.40583957e+09, 8.12277315e+09, 1.02280655e+10,
#          1.28919271e+10, 1.43605765e+10, 1.55017970e+10, 2.09069971e+10,
#          2.24169261e+10, 2.62387558e+10, 3.16360438e+10, 3.97637066e+10,
#          4.74689935e+10, 5.97253124e+10, 6.87157597e+10, 7.78783248e+10]),
#   'omega': array([  8390.85614768,  34853.84317649,  36227.44179366,  46497.21570915,
#           64039.50091543,  86057.18777304,  90126.42867662, 101133.89863907,
#          113542.62232846, 119835.62274208, 124506.21271591, 144592.5207888 ,
#          149722.83106491, 161983.81325127, 177865.24044826, 199408.3914864 ,
#          217873.80176626, 244387.62729633, 262136.91019076, 279066.88226624]),
#   'frequency': array([ 1335.44623268,  5547.16142729,  5765.77643704,  7400.26172012,
#          10192.20312383, 13696.42682267, 14344.0666271 , 16095.95988256,
#          18070.86959519, 19072.4317179 , 19815.77919939, 23012.61441766,
#          23829.12865769, 25780.52457981, 28308.13222157, 31736.83119906,
#          34675.69252132, 38895.49891471, 41720.3850237 , 44414.87376592]),
#   'SolverCalls': 63},
#  (4, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2451e040438>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2451e16f5f8>,
#   'TotalLienarOpCall': 8990,
#   'AvgLienarOpCall': 142.6984126984127,
#   'eigenvalues': array([1.36796235e+08, 1.23183075e+09, 1.33032212e+09, 2.10407628e+09,
#          4.12123712e+09, 7.41945781e+09, 8.16768383e+09, 1.02599558e+10,
#          1.19506660e+10, 1.40415307e+10, 1.62661383e+10, 2.09219262e+10,
#          2.26117946e+10, 2.60927077e+10, 3.54356450e+10, 4.21099536e+10,
#          4.78102342e+10, 5.94254226e+10, 6.22967865e+10, 7.51112286e+10]),
#   'omega': array([ 11695.99226504,  35097.44648044,  36473.58113949,  45870.21120579,
#           64196.86226685,  86136.27466756,  90375.23902756, 101291.44013921,
#          109319.10181927, 118496.96507524, 127538.77175015, 144644.13640412,
#          150372.18702125, 161532.37351108, 188243.57889047, 205207.09939154,
#          218655.5148255 , 243773.30164198, 249593.24216944, 274064.27830634]),
#   'frequency': array([ 1861.47498335,  5585.93209726,  5804.95073061,  7300.47085407,
#          10217.24796076, 13709.01389286, 14383.66602435, 16121.03339105,
#          17398.6754289 , 18859.37773311, 20298.4259599 , 23020.82929797,
#          23932.47686797, 25708.67571366, 29959.89608573, 32659.72422571,
#          34800.10601878, 38797.72595015, 39723.9982536 , 43618.68461737]),
#   'SolverCalls': 63},
#  (4, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245065639e8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2451df20da0>,
#   'TotalLienarOpCall': 5062,
#   'AvgLienarOpCall': 80.34920634920636,
#   'eigenvalues': array([1.36796235e+08, 1.23183075e+09, 1.33032212e+09, 2.10407628e+09,
#          4.12123712e+09, 7.41945781e+09, 8.16768383e+09, 1.02599558e+10,
#          1.19506660e+10, 1.40415307e+10, 1.62661383e+10, 2.09219262e+10,
#          2.26117946e+10, 2.60927077e+10, 3.54356450e+10, 4.21099536e+10,
#          4.78102342e+10, 5.94254226e+10, 6.22967865e+10, 7.51112286e+10]),
#   'omega': array([ 11695.99226505,  35097.44648043,  36473.5811395 ,  45870.21120578,
#           64196.86226685,  86136.27466757,  90375.23902755, 101291.44013921,
#          109319.10181929, 118496.96507524, 127538.77175018, 144644.13640411,
#          150372.18702127, 161532.37351112, 188243.57889053, 205207.09939152,
#          218655.51482545, 243773.30164186, 249593.24216937, 274064.2783064 ]),
#   'frequency': array([ 1861.47498335,  5585.93209726,  5804.95073062,  7300.47085407,
#          10217.24796076, 13709.01389287, 14383.66602435, 16121.03339105,
#          17398.67542891, 18859.37773311, 20298.42595991, 23020.82929797,
#          23932.47686797, 25708.67571366, 29959.89608574, 32659.72422571,
#          34800.10601877, 38797.72595013, 39723.99825359, 43618.68461738]),
#   'SolverCalls': 63},
#  (4, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245065eeb00>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24520631a90>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([1.36796235e+08, 1.23183075e+09, 1.33032212e+09, 2.10407628e+09,
#          4.12123712e+09, 7.41945781e+09, 8.16768383e+09, 1.02599558e+10,
#          1.19506660e+10, 1.40415307e+10, 1.62661383e+10, 2.09219262e+10,
#          2.26117946e+10, 2.60927077e+10, 3.54356450e+10, 4.21099536e+10,
#          4.78102342e+10, 5.94254226e+10, 6.22967865e+10, 7.51112286e+10]),
#   'omega': array([ 11695.99226503,  35097.44648044,  36473.5811395 ,  45870.21120575,
#           64196.86226686,  86136.2746676 ,  90375.23902758, 101291.44013921,
#          109319.10181924, 118496.96507526, 127538.7717502 , 144644.13640412,
#          150372.18702127, 161532.3735111 , 188243.57889052, 205207.09939143,
#          218655.51482539, 243773.3016419 , 249593.24216942, 274064.27830632]),
#   'frequency': array([ 1861.47498334,  5585.93209726,  5804.95073061,  7300.47085407,
#          10217.24796076, 13709.01389287, 14383.66602435, 16121.03339105,
#          17398.6754289 , 18859.37773311, 20298.42595991, 23020.82929797,
#          23932.47686797, 25708.67571366, 29959.89608574, 32659.7242257 ,
#          34800.10601876, 38797.72595014, 39723.9982536 , 43618.68461736]),
#   'SolverCalls': 63},
#  (5, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x245066a16d8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x245066a1d30>,
#   'TotalLienarOpCall': 84674,
#   'AvgLienarOpCall': 1344.031746031746,
#   'eigenvalues': array([2.83887442e+08, 1.26115681e+09, 2.06963794e+09, 2.37713583e+09,
#          4.60949705e+09, 7.70842405e+09, 1.02187535e+10, 1.15359000e+10,
#          1.25582889e+10, 1.54055804e+10, 1.91676696e+10, 2.25478442e+10,
#          2.85088960e+10, 2.97485855e+10, 3.14451201e+10, 4.00004424e+10,
#          4.69799325e+10, 6.05367066e+10, 6.39537541e+10, 7.57747648e+10]),
#   'omega': array([ 16848.95966206,  35512.7696597 ,  45493.27358431,  48755.87997369,
#           67893.27689572,  87797.63124953, 101087.85029506, 107405.30732135,
#          112063.77136883, 124119.21837615, 138447.35301159, 150159.39614073,
#          168845.77588718, 172477.78253139, 177327.71944526, 200001.10593281,
#          216748.5467651 , 246042.08301235, 252890.7947581 , 275272.16487611]),
#   'frequency': array([ 2681.59521617,  5652.03283423,  7240.47936838,  7759.73930261,
#          10805.55062066, 13973.42700512, 16088.63106099, 17094.0855745 ,
#          17835.50315487, 19754.18713727, 22034.58058978, 23898.61014749,
#          26872.63985263, 27450.6916634 , 28222.58309693, 31831.16463305,
#          34496.60262565, 39158.81372004, 40248.82004819, 43810.92573564]),
#   'SolverCalls': 63},
#  (5, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24538f28278>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24506722940>,
#   'TotalLienarOpCall': 9785,
#   'AvgLienarOpCall': 155.31746031746033,
#   'eigenvalues': array([2.83887442e+08, 1.26115681e+09, 2.06963794e+09, 2.37713583e+09,
#          4.60949705e+09, 7.70842405e+09, 1.02187535e+10, 1.15359000e+10,
#          1.25582889e+10, 1.54055804e+10, 1.91676696e+10, 2.25478442e+10,
#          2.85088960e+10, 2.97485855e+10, 3.14451201e+10, 4.00004424e+10,
#          4.69799325e+10, 6.05367066e+10, 6.39537541e+10, 7.57747648e+10]),
#   'omega': array([ 16848.95966206,  35512.7696597 ,  45493.27358431,  48755.87997369,
#           67893.27689572,  87797.63124953, 101087.85029507, 107405.30732139,
#          112063.77136885, 124119.21837618, 138447.35301162, 150159.39614081,
#          168845.77588724, 172477.78253134, 177327.71944526, 200001.10593282,
#          216748.5467651 , 246042.08301236, 252890.79475812, 275272.16487604]),
#   'frequency': array([ 2681.59521617,  5652.03283423,  7240.47936837,  7759.73930261,
#          10805.55062066, 13973.42700512, 16088.63106099, 17094.0855745 ,
#          17835.50315487, 19754.18713727, 22034.58058979, 23898.6101475 ,
#          26872.63985264, 27450.69166339, 28222.58309693, 31831.16463305,
#          34496.60262565, 39158.81372004, 40248.82004819, 43810.92573563]),
#   'SolverCalls': 63},
#  (5, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24539030898>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539004b00>,
#   'TotalLienarOpCall': 5146,
#   'AvgLienarOpCall': 81.68253968253968,
#   'eigenvalues': array([2.83887442e+08, 1.26115681e+09, 2.06963794e+09, 2.37713583e+09,
#          4.60949705e+09, 7.70842405e+09, 1.02187535e+10, 1.15359000e+10,
#          1.25582889e+10, 1.54055804e+10, 1.91676696e+10, 2.25478442e+10,
#          2.85088960e+10, 2.97485855e+10, 3.14451201e+10, 4.00004424e+10,
#          4.69799325e+10, 6.05367066e+10, 6.39537541e+10, 7.57747648e+10]),
#   'omega': array([ 16848.95966206,  35512.7696597 ,  45493.27358431,  48755.87997369,
#           67893.27689571,  87797.63124954, 101087.85029506, 107405.30732136,
#          112063.77136885, 124119.21837616, 138447.35301163, 150159.39614076,
#          168845.77588719, 172477.78253134, 177327.71944537, 200001.10593285,
#          216748.54676505, 246042.08301249, 252890.79475813, 275272.16487595]),
#   'frequency': array([ 2681.59521617,  5652.03283423,  7240.47936838,  7759.73930261,
#          10805.55062066, 13973.42700512, 16088.63106099, 17094.0855745 ,
#          17835.50315487, 19754.18713727, 22034.58058979, 23898.6101475 ,
#          26872.63985263, 27450.69166339, 28222.58309694, 31831.16463306,
#          34496.60262564, 39158.81372006, 40248.82004819, 43810.92573562]),
#   'SolverCalls': 63},
#  (5, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2451b802f28>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24539092a90>,
#   'TotalLienarOpCall': 9861,
#   'AvgLienarOpCall': 156.52380952380952,
#   'eigenvalues': array([2.83887442e+08, 1.26115681e+09, 2.06963794e+09, 2.37713583e+09,
#          4.60949705e+09, 7.70842405e+09, 1.02187535e+10, 1.15359000e+10,
#          1.25582889e+10, 1.54055804e+10, 1.91676696e+10, 2.25478442e+10,
#          2.85088960e+10, 2.97485855e+10, 3.14451201e+10, 4.00004424e+10,
#          4.69799325e+10, 6.05367066e+10, 6.39537541e+10, 7.57747648e+10]),
#   'omega': array([ 16848.95966206,  35512.76965971,  45493.27358431,  48755.87997369,
#           67893.27689572,  87797.63124953, 101087.85029508, 107405.30732136,
#          112063.77136886, 124119.21837621, 138447.3530116 , 150159.39614075,
#          168845.7758872 , 172477.78253141, 177327.71944534, 200001.10593281,
#          216748.546765  , 246042.08301242, 252890.79475811, 275272.16487572]),
#   'frequency': array([ 2681.59521617,  5652.03283423,  7240.47936837,  7759.73930261,
#          10805.55062066, 13973.42700512, 16088.631061  , 17094.0855745 ,
#          17835.50315487, 19754.18713728, 22034.58058979, 23898.6101475 ,
#          26872.63985263, 27450.6916634 , 28222.58309694, 31831.16463305,
#          34496.60262564, 39158.81372005, 40248.82004819, 43810.92573558]),
#   'SolverCalls': 63},
#  (5, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24600ce8860>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2451df32c50>,
#   'TotalLienarOpCall': 5151,
#   'AvgLienarOpCall': 81.76190476190476,
#   'eigenvalues': array([2.83887442e+08, 1.26115681e+09, 2.06963794e+09, 2.37713583e+09,
#          4.60949705e+09, 7.70842405e+09, 1.02187535e+10, 1.15359000e+10,
#          1.25582889e+10, 1.54055804e+10, 1.91676696e+10, 2.25478442e+10,
# ...
#          151641.89905151, 157814.60548646, 167583.06752567, 186668.81121037,
#          202166.44971441, 208141.93282368, 212317.13493137, 227952.02865543,
#          232674.40970113, 245408.94520001, 252289.23121812, 280511.7611018 ]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334951, 11849.00901433,
#          13382.58564394, 15842.22212625, 17706.0299841 , 20658.39877342,
#          24134.55781389, 25116.97455527, 26671.67357521, 29709.26402522,
#          32175.78979939, 33126.81747359, 33791.32152744, 36279.69214834,
#          37031.28243492, 39058.04670755, 40153.07823722, 44644.83337476]),
#   'SolverCalls': 63},
#  (11, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x246f7f9b898>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x246f7eea3c8>,
#   'TotalLienarOpCall': 11496,
#   'AvgLienarOpCall': 182.47619047619048,
#   'eigenvalues': array([8.16679096e+08, 2.08732449e+09, 4.57466217e+09, 5.54273093e+09,
#          7.07033187e+09, 9.90813541e+09, 1.23766220e+10, 1.68481822e+10,
#          2.29952655e+10, 2.49054497e+10, 2.80840845e+10, 3.48452451e+10,
#          4.08712734e+10, 4.33230642e+10, 4.50785658e+10, 5.19621274e+10,
#          5.41373809e+10, 6.02255504e+10, 6.36498562e+10, 7.86868481e+10]),
#   'omega': array([ 28577.59780137,  45687.24642746,  67636.2489307 ,  74449.51934345,
#           84085.2654901 ,  99539.61729669, 111250.26744461, 129800.54764305,
#          151641.89905152, 157814.6054865 , 167583.06752577, 186668.81121027,
#          202166.44971461, 208141.93282368, 212317.13493156, 227952.02865492,
#          232674.40970156, 245408.94519993, 252289.23121792, 280511.76110144]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334951, 11849.00901433,
#          13382.58564394, 15842.22212624, 17706.02998411, 20658.39877343,
#          24134.55781389, 25116.97455527, 26671.67357523, 29709.2640252 ,
#          32175.78979942, 33126.81747359, 33791.32152747, 36279.69214826,
#          37031.28243499, 39058.04670754, 40153.07823719, 44644.83337471]),
#   'SolverCalls': 63},
#  (11, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24721955a90>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24720956470>,
#   'TotalLienarOpCall': 5851,
#   'AvgLienarOpCall': 92.87301587301587,
#   'eigenvalues': array([8.16679096e+08, 2.08732449e+09, 4.57466217e+09, 5.54273093e+09,
#          7.07033187e+09, 9.90813541e+09, 1.23766220e+10, 1.68481822e+10,
#          2.29952655e+10, 2.49054497e+10, 2.80840845e+10, 3.48452451e+10,
#          4.08712734e+10, 4.33230642e+10, 4.50785658e+10, 5.19621274e+10,
#          5.41373809e+10, 6.02255504e+10, 6.36498562e+10, 7.86868481e+10]),
#   'omega': array([ 28577.59780137,  45687.24642745,  67636.2489307 ,  74449.51934346,
#           84085.2654901 ,  99539.61729673, 111250.26744459, 129800.54764307,
#          151641.89905148, 157814.6054864 , 167583.06752578, 186668.81121041,
#          202166.44971459, 208141.93282377, 212317.13493144, 227952.02865517,
#          232674.40970157, 245408.94520016, 252289.23121754, 280511.7611016 ]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334951, 11849.00901433,
#          13382.58564394, 15842.22212625, 17706.0299841 , 20658.39877343,
#          24134.55781388, 25116.97455526, 26671.67357523, 29709.26402522,
#          32175.78979942, 33126.8174736 , 33791.32152745, 36279.6921483 ,
#          37031.28243499, 39058.04670757, 40153.07823712, 44644.83337473]),
#   'SolverCalls': 63},
#  (11, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x246f7ff7f60>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24721955390>,
#   'TotalLienarOpCall': 11616,
#   'AvgLienarOpCall': 184.38095238095238,
#   'eigenvalues': array([8.16679096e+08, 2.08732449e+09, 4.57466217e+09, 5.54273093e+09,
#          7.07033187e+09, 9.90813541e+09, 1.23766220e+10, 1.68481822e+10,
#          2.29952655e+10, 2.49054497e+10, 2.80840845e+10, 3.48452451e+10,
#          4.08712734e+10, 4.33230642e+10, 4.50785658e+10, 5.19621274e+10,
#          5.41373809e+10, 6.02255504e+10, 6.36498562e+10, 7.86868481e+10]),
#   'omega': array([ 28577.59780138,  45687.24642746,  67636.24893071,  74449.51934345,
#           84085.2654901 ,  99539.61729669, 111250.26744461, 129800.54764307,
#          151641.89905145, 157814.6054864 , 167583.06752585, 186668.81121029,
#          202166.4497147 , 208141.93282371, 212317.13493149, 227952.02865501,
#          232674.40970169, 245408.94520022, 252289.23121736, 280511.7611015 ]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334952, 11849.00901433,
#          13382.58564394, 15842.22212624, 17706.0299841 , 20658.39877343,
#          24134.55781388, 25116.97455526, 26671.67357524, 29709.26402521,
#          32175.78979943, 33126.81747359, 33791.32152746, 36279.69214827,
#          37031.28243501, 39058.04670758, 40153.0782371 , 44644.83337472]),
#   'SolverCalls': 63},
#  (11, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24721a35fd0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24721955320>,
#   'TotalLienarOpCall': 5857,
#   'AvgLienarOpCall': 92.96825396825396,
#   'eigenvalues': array([8.16679096e+08, 2.08732449e+09, 4.57466217e+09, 5.54273093e+09,
#          7.07033187e+09, 9.90813541e+09, 1.23766220e+10, 1.68481822e+10,
#          2.29952655e+10, 2.49054497e+10, 2.80840845e+10, 3.48452451e+10,
#          4.08712734e+10, 4.33230642e+10, 4.50785658e+10, 5.19621274e+10,
#          5.41373809e+10, 6.02255504e+10, 6.36498562e+10, 7.86868481e+10]),
#   'omega': array([ 28577.59780137,  45687.24642746,  67636.24893071,  74449.51934346,
#           84085.26549007,  99539.61729672, 111250.2674446 , 129800.54764312,
#          151641.89905153, 157814.60548658, 167583.06752567, 186668.81121043,
#          202166.44971458, 208141.93282368, 212317.13493151, 227952.0286551 ,
#          232674.40970142, 245408.9452002 , 252289.23121762, 280511.76110167]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334952, 11849.00901433,
#          13382.58564394, 15842.22212625, 17706.0299841 , 20658.39877344,
#          24134.55781389, 25116.97455529, 26671.67357521, 29709.26402523,
#          32175.78979941, 33126.81747359, 33791.32152746, 36279.69214828,
#          37031.28243497, 39058.04670758, 40153.07823714, 44644.83337474]),
#   'SolverCalls': 63},
#  (11, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24721a35e80>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24721aa1048>,
#   'TotalLienarOpCall': 63,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([8.16679096e+08, 2.08732449e+09, 4.57466217e+09, 5.54273093e+09,
#          7.07033187e+09, 9.90813541e+09, 1.23766220e+10, 1.68481822e+10,
#          2.29952655e+10, 2.49054497e+10, 2.80840845e+10, 3.48452451e+10,
#          4.08712734e+10, 4.33230642e+10, 4.50785658e+10, 5.19621274e+10,
#          5.41373809e+10, 6.02255504e+10, 6.36498562e+10, 7.86868481e+10]),
#   'omega': array([ 28577.59780137,  45687.24642746,  67636.2489307 ,  74449.51934346,
#           84085.26549007,  99539.6172967 , 111250.2674446 , 129800.54764304,
#          151641.89905148, 157814.60548647, 167583.06752569, 186668.81121042,
#          202166.44971464, 208141.93282377, 212317.13493141, 227952.02865508,
#          232674.40970136, 245408.94520019, 252289.23121772, 280511.76110166]),
#   'frequency': array([ 4548.26595178,  7271.35110519, 10764.64334951, 11849.00901433,
#          13382.58564394, 15842.22212624, 17706.0299841 , 20658.39877343,
#          24134.55781389, 25116.97455527, 26671.67357522, 29709.26402523,
#          32175.78979942, 33126.8174736 , 33791.32152744, 36279.69214828,
#          37031.28243496, 39058.04670758, 40153.07823715, 44644.83337474]),
#   'SolverCalls': 63},
#  (12, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x24721b45f60>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24721b45d30>,
#   'TotalLienarOpCall': 79813,
#   'AvgLienarOpCall': 1266.873015873016,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083396,  71667.53827891,  74176.33552206,
#           87449.99588865,  92143.51271871, 111348.77788748, 130868.80243336,
#          151565.15762223, 158702.18807215, 185188.01827999, 186601.68822821,
#          199520.98300658, 202076.74510344, 210166.72639127, 221392.04335241,
#          233841.18365922, 260754.48748444, 265607.3969031 , 267786.91375131]),
#   'frequency': array([ 4504.9735851 ,  7271.88338401, 11406.24297632, 11805.53045878,
#          13918.09911905, 14665.09552303, 17721.70840803, 20828.41680379,
#          24122.34403608, 25258.23771118, 29473.58851065, 29698.58107081,
#          31754.75069605, 32161.51286713, 33449.07337861, 35235.63806075,
#          37216.98027782, 41500.36561654, 42272.7301389 , 42619.61101884]),
#   'SolverCalls': 63},
#  (12, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2474b491a90>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x246ce3365f8>,
#   'TotalLienarOpCall': 11382,
#   'AvgLienarOpCall': 180.66666666666666,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083397,  71667.53827893,  74176.33552206,
#           87449.99588863,  92143.51271873, 111348.77788748, 130868.80243341,
#          151565.15762224, 158702.18807213, 185188.01827992, 186601.68822814,
#          199520.98300686, 202076.74510345, 210166.72639141, 221392.04335243,
#          233841.18365949, 260754.48748474, 265607.39690316, 267786.91375113]),
#   'frequency': array([ 4504.9735851 ,  7271.88338401, 11406.24297632, 11805.53045878,
#          13918.09911904, 14665.09552304, 17721.70840803, 20828.41680379,
#          24122.34403608, 25258.23771118, 29473.58851064, 29698.5810708 ,
#          31754.7506961 , 32161.51286714, 33449.07337863, 35235.63806075,
#          37216.98027787, 41500.36561659, 42272.73013891, 42619.61101881]),
#   'SolverCalls': 63},
#  (12, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2474b45e470>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x24721ae4f28>,
#   'TotalLienarOpCall': 5831,
#   'AvgLienarOpCall': 92.55555555555556,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083396,  71667.53827892,  74176.33552206,
#           87449.99588865,  92143.51271873, 111348.77788747, 130868.80243342,
#          151565.15762227, 158702.18807207, 185188.01827986, 186601.68822818,
#          199520.98300682, 202076.74510362, 210166.7263914 , 221392.04335253,
#          233841.18365945, 260754.48748471, 265607.39690313, 267786.91375114]),
#   'frequency': array([ 4504.9735851 ,  7271.88338401, 11406.24297632, 11805.53045878,
#          13918.09911904, 14665.09552304, 17721.70840803, 20828.4168038 ,
#          24122.34403609, 25258.23771117, 29473.58851063, 29698.58107081,
#          31754.75069609, 32161.51286716, 33449.07337863, 35235.63806077,
#          37216.98027786, 41500.36561658, 42272.7301389 , 42619.61101882]),
#   'SolverCalls': 63},
#  (12, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2474b56ffd0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2474b50d940>,
#   'TotalLienarOpCall': 11334,
#   'AvgLienarOpCall': 179.9047619047619,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083396,  71667.53827893,  74176.33552207,
#           87449.99588863,  92143.51271874, 111348.77788749, 130868.80243341,
#          151565.1576223 , 158702.18807225, 185188.01827998, 186601.68822822,
#          199520.98300672, 202076.74510341, 210166.72639136, 221392.04335255,
#          233841.18365925, 260754.48748431, 265607.39690319, 267786.91375124]),
#   'frequency': array([ 4504.9735851 ,  7271.88338401, 11406.24297632, 11805.53045878,
#          13918.09911904, 14665.09552304, 17721.70840804, 20828.41680379,
#          24122.34403609, 25258.2377112 , 29473.58851065, 29698.58107081,
#          31754.75069607, 32161.51286713, 33449.07337863, 35235.63806077,
#          37216.98027783, 41500.36561652, 42272.73013891, 42619.61101883]),
#   'SolverCalls': 63},
#  (12, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2474b491a20>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2474b56fef0>,
#   'TotalLienarOpCall': 5838,
#   'AvgLienarOpCall': 92.66666666666667,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083396,  71667.53827892,  74176.33552206,
#           87449.99588865,  92143.51271872, 111348.77788747, 130868.80243337,
#          151565.15762223, 158702.18807224, 185188.01827981, 186601.68822817,
#          199520.98300683, 202076.74510364, 210166.72639144, 221392.0433525 ,
#          233841.18365946, 260754.48748458, 265607.39690312, 267786.91375126]),
#   'frequency': array([ 4504.9735851 ,  7271.88338401, 11406.24297632, 11805.53045878,
#          13918.09911904, 14665.09552304, 17721.70840803, 20828.41680379,
#          24122.34403608, 25258.2377112 , 29473.58851062, 29698.58107081,
#          31754.75069609, 32161.51286716, 33449.07337864, 35235.63806077,
#          37216.98027786, 41500.36561656, 42272.7301389 , 42619.61101884]),
#   'SolverCalls': 63},
#  (12, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2474b56f3c8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2474b5cf978>,
#   'TotalLienarOpCall': 63,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([8.01206076e+08, 2.08763009e+09, 5.13623604e+09, 5.50212875e+09,
#          7.64750178e+09, 8.49042694e+09, 1.23985503e+10, 1.71266435e+10,
#          2.29719970e+10, 2.51863845e+10, 3.42946021e+10, 3.48201900e+10,
#          3.98086227e+10, 4.08350109e+10, 4.41700529e+10, 4.90144369e+10,
#          5.46816992e+10, 6.79929027e+10, 7.05472893e+10, 7.17098312e+10]),
#   'omega': array([ 28305.58383913,  45690.59083398,  71667.53827895,  74176.33552208,
#           87449.99588865,  92143.51271871, 111348.77788748, 130868.80243337,
#          151565.15762227, 158702.18807214, 185188.01827993, 186601.68822816,
#          199520.9830068 , 202076.74510357, 210166.72639134, 221392.04335241,
#          233841.18365941, 260754.48748455, 265607.39690309, 267786.91375129]),
#   'frequency': array([ 4504.9735851 ,  7271.88338402, 11406.24297632, 11805.53045878,
#          13918.09911904, 14665.09552303, 17721.70840803, 20828.41680379,
#          24122.34403609, 25258.23771118, 29473.58851064, 29698.5810708 ,
#          31754.75069609, 32161.51286715, 33449.07337862, 35235.63806075,
#          37216.98027786, 41500.36561656, 42272.7301389 , 42619.61101884]),
#   'SolverCalls': 63}}

# %%
def create_sector_list(my_comp,node_diam):
    sector_list = []
    for i in range(n_sector):
        sector_i = create_rotated_component(my_comp,s,sector_id=i, node_id=node_diam, theta=theta, unit='rad', dimension=3)
        sector_list.append(sector_i)
    return sector_list

def plot_sector_list(sector_list, ax1):
    ax1.clear()
    plot_list = []
    reference = True
    highlight = int(n_sector/2)
    for k,sector_i in enumerate(sector_list):
        displacement = sector_i.u_output
        m_i = sector_i.mesh_class
        if reference:
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id, facecolor=0.8*np.array((1,1,1)))    
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, 
                                      alpha=1,edgecolor=np.array((1,1,1))*0.75,linewidth=0.4,color=np.array((1,1,1)))   
                                      #alpha=1,edgecolor='black',linewidth=0.5,color=np.array((1,1,1))*0.75)   
            collections=[]
            reference = False
        else:
            
            
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id)
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, 
                                      alpha=1,edgecolor=np.array((1,1,1))*0.75,linewidth=0.4,color=np.array((1,1,1)))   
            collections = pltmesh.ax.collections
        
        if k==highlight:
            pltmesh.edgecolor='black' 
            pltmesh.linewidth=0.4,
            pltmesh.color=np.array((1,1,1))*0.75
        
        plot_list.append(pltmesh)
        
        
    return plot_list
        
precond_id = 2        
comp2new_1 = res_dict[0,precond_id]['comp']
comp2new_2 = res_dict[1,precond_id]['comp']
comp2new_3 = res_dict[2,precond_id]['comp']
sector_list_1 = create_sector_list(comp2new_1,0)
sector_list_2 = create_sector_list(comp2new_2,1)
sector_list_3 = create_sector_list(comp2new_3,2)
sector_list = [sector_list_1,
               sector_list_2,
               sector_list_3]

# %%
from ipywidgets import interact
import mpl_toolkits.mplot3d as a3

fig1 = plt.figure(figsize=(10,10))
axes_list = []
plt_list = []
counter = 0
for i in range(3):
    for j in range(3):
        ax_i = fig1.add_subplot(3,3,counter+1,projection='3d')
        axes_list.append(ax_i)
        plt_list.append(plot_sector_list(sector_list[i], ax_i))
        counter += 1
plt.rc('text', usetex=True)

@interact(factor=(-1.0,1.0,0.05),mode_id=(0,n_modes,1))
def plot2(factor=-0.75,mode_id=0):
    #ax1.clear()
    #for sector_i in sector_list:
    #    amfe.plot_system_solution(sector_i, factor=10*factor, ax = ax1, u_id = mode_id)
    #bc = np.array([-250,250])*.6
    global bc
    i = 0
    j = 0
    for plt_list_i in plt_list:
        collections = []
        
        for plot_obj in plt_list_i:
            plot_obj.show(factor=1000*factor,plot_nodes=False,displacement_id=mode_id+i, collections=collections)
            plot_obj.set_equal_axis_lim(bc*0.7)
            plot_obj.ax.set_xlabel('x [mm]')
            plot_obj.ax.set_ylabel('y [mm]')
            plot_obj.ax.set_zlabel('z [mm]')
            #plot_obj.ax.set_title('$n$ = %i, $omega& = %f ' %(j,res_dict[j,precond_id]['omega'][i]))
            #plot_obj.ax.text(0,0,0, '$n$ = %i, $omega& = %f ' %(j,res_dict[j,precond_id]['omega'][i]))
            #label_str = r'$n$ = %i, $\omega$ = %0.2f [rad/s]' %(j,res_dict[j,precond_id]['omega'][i].real)
            label_str = r'$n$ = %i, $f$ = %0.2f [Hz]' %(j,res_dict[j,precond_id]['frequency'][i].real)
            #transform=ax.transAxes
            plot_obj.ax.text2D(0.2, 0.95, label_str, transform=plot_obj.ax.transAxes)
        if i<2:
            i+=1
        else:
            i=0
            j+=1
# Out:
# <img src="data:image/png;base64,..." width="1000">
# interactive(children=(FloatSlider(value=-0.75, description='factor', max=1.0, min=-1.0, step=0.05), IntSlider(…

# %%
columns = []
for i in range(len(P_n_list)):
    columns.append('ND' + str(i))
    
index = ['I','$P(incK)^{-1}P$','$PK^{-1}P$','inc(K)^-1','K^-1','(PK^P)^-1']


data = np.zeros((len(list_precond),len(P_n_list)),dtype=np.float)

for i in range(len(P_n_list)):
    for j in range(len(list_precond)):
        data[j,i] = res_dict[i,j]['AvgLienarOpCall']
        
df = pd.DataFrame(data, index=index, columns=columns)

df
# Out:
#                          ND0          ND1          ND2          ND3  \
# I                1676.825397  1438.269841  1421.809524  1610.825397
# $P(incK)^{-1}P$   567.952381   354.920635   360.063492   367.126984
# $PK^{-1}P$        526.428571   300.238095   303.523810    76.111111
# inc(K)^-1         568.285714   354.619048   409.134615   137.809524
# K^-1              526.365079    68.571429   352.192308   356.846154
# (PK^P)^-1         283.115385     1.015873     1.015873     1.015873
#
#                          ND4          ND5          ND6          ND7  \
# I                1371.333333  1344.031746  1323.396825  1307.142857
# $P(incK)^{-1}P$   141.984127   155.317460   163.444444   171.111111
# $PK^{-1}P$        310.444444    81.682540    86.682540    89.365079
# inc(K)^-1         142.698413   156.523810   162.380952   170.920635
# K^-1               80.349206    81.761905    86.428571    89.317460
# (PK^P)^-1           1.015873     1.015873     1.000000     1.000000
#
#                          ND8          ND9         ND10         ND11  \
# I                1295.047619  1286.111111  1272.047619  1268.746032
# $P(incK)^{-1}P$   178.619048   176.809524   181.650794   182.476190
# $PK^{-1}P$         90.698413    90.349206    92.841270    92.873016
# inc(K)^-1         178.301587   176.793651   182.476190   184.380952
# K^-1               91.031746    90.857143    92.777778    92.968254
# (PK^P)^-1           1.000000     1.000000     1.000000     1.000000
#
#                         ND12
# I                1266.873016
# $P(incK)^{-1}P$   180.666667
# $PK^{-1}P$         92.555556
# inc(K)^-1         179.904762
# K^-1               92.666667
# (PK^P)^-1           1.000000

# %%
print('Number of dofs is equal to %i ' %K_sector.shape[0])
# Out:
# Number of dofs is equal to 1467

# %%
fig1.savefig('3D_simple_turbine_with_24_sectors_hertz_mass_scaling.png')

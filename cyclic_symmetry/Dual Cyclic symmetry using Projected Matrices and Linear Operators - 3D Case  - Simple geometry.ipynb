# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

import scipy.sparse as sparse
import scipy.linalg as linalg
from scipy.sparse.linalg import LinearOperator
import numpy as np
import collections
import copy

import amfe
from amfe.utils.utils import OrderedSet
from amfe.cyclic.cyclic import SelectionOperator, apply_cyclic_symmetry, get_all_dofs, rotate_u, set_cyclic_modes_to_component
from amfe.cyclic.cyclic import create_voigt_rotation_matrix, assemble_cyclic_modes, cyclic_symmetry_modal_analysis, Cyclic_Symmetry_Modal_Analysis
from amfe.cyclic.cyclic import create_rotated_component, create_voigt_rotation_matrix, Cyclic_Component
from amfe.utils.utils import get_dofs
from amfe.linalg.arnoldi import arnoldi_iteration, inverse_arnoldi_iteration, general_inverse_arnoldi_iteration, generalized_arnoldi_iteration
from amfe.linalg.arnoldi import lanczos, is_eigvec, nullspace, LinearSys, power_iteration, ProjLinearSys, compute_modes, eigvec_error_vector, is_nullspace
from amfe.linalg.arnoldi import is_moore_pensore_inverse, ProjPrecondLinearSys
from amfe.contact import Cyclic_Contact
from amfe.units import convert
import pandas as pd
import logging 
from amfe.wrappers.ansys_wrapper import read_ansys_sparse_matrix

#msh_file = r'meshes\one_forth_disk_quad.msh'
#theta = np.pi/2.0 #

cases_dict = {}

cases_dict[1] =  {'msh_file' : r'meshes\simple_blade_disc.inp', 'msh_obj' : r'amfe_mesh_obj\simple_blade_disc.pkl',
                  'theta' : np.pi/4.0,
                  'scale' : 1000,
                  'tol_radius' : 1.0e-3,
                   'bc' : np.array([-50,50])}

cases_dict[2] = {'msh_file' : r'meshes\3D_simple_bladed_disk.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk.pkl',
                 'theta' : 2*np.pi/81.0,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}


cases_dict[3] = {'msh_file' : r'meshes\3D_simple_bladed_disk_course.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_course.pkl',
                 'theta' : 2*np.pi/81.0,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}


cases_dict[4] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-300,300])}

cases_dict[5] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_V2.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_V2.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

cases_dict[6] = {'msh_file' : r'meshes\3d_simple_bladed_disk_24_sector.msh', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_gmsh.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}


cases_dict[7] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_v3.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_v3.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

cases_dict[8] = {'msh_file' : r'meshes\3D_simple_bladed_disk_24_sectors_course_quad.inp', 'msh_obj' : r'amfe_mesh_obj\3D_simple_bladed_disk_24_sectors_course_quad.pkl',
                 'theta' : 2*np.pi/24,
                 'scale' : 1000,
                 'tol_radius' : 1.1e0,
                 'bc' : np.array([-200,200])}

#unpack case dict
case_id = 7
msh_file = cases_dict[case_id]['msh_file']
msh_obj = cases_dict[case_id]['msh_obj']
theta = cases_dict[case_id]['theta']
scale = cases_dict[case_id]['scale']
n_sector = int((2.0*np.pi)/abs(theta))
tol_radius = cases_dict[case_id]['tol_radius']
bc = cases_dict[case_id]['bc']

try:
    m = amfe.load_obj(msh_obj)
except:
    m = amfe.Mesh()
    if case_id==6:
        m.import_msh(msh_file,scale)
    else:
        m.import_inp(msh_file,scale)
    amfe.save_object(m,msh_obj)
# Out:
# Python was not able to load the fast fortran assembly routines.
#
# Python was not able to load the fast fortran material routines.

# %%
pltmsh = amfe.Plot3DMesh(m,boundaries=False,plot_nodes=False,alpha=0.5)
pltmsh.show()
pltmsh.ax.set_xlim(bc)
pltmsh.ax.set_ylim(bc)
pltmsh.ax.set_zlim(bc)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-50, 50)

# %%
m.get_phys_group_types()
# Out:
# {'DIRICHLET_ELSET',
#  'HIGH_ELSET',
#  'LOW_ELSET',
#  'SOLID_1_1_ELSET',
#  'SOLID_1_1_SOLID_ELSET',
#  'TOP_ELSET',
#  'TOP_HIGH_ELSET',
#  'TOP_LOW_ELSET'}

# %%
m.change_tag_in_eldf('phys_group','TOP_HIGH_ELSET','HIGH_ELSET')
m.change_tag_in_eldf('phys_group','TOP_LOW_ELSET','LOW_ELSET')
m.change_tag_in_eldf('phys_group','BODY_1_1_SOLID_ELSET','SOLID_1_1_SOLID_ELSET')
m.change_tag_in_eldf('phys_group','LEFT_ELSET','LOW_ELSET')
m.change_tag_in_eldf('phys_group','RIGHT_ELSET','HIGH_ELSET')
                     
dirsub = m.get_submesh('phys_group', 'DIRICHLET_ELSET')
cyclic_left = m.get_submesh('phys_group', 'LOW_ELSET')
cyclic_right = m.get_submesh('phys_group', 'HIGH_ELSET')
m.get_phys_group_types()
# Out:
# {'DIRICHLET_ELSET',
#  'HIGH_ELSET',
#  'LOW_ELSET',
#  'SOLID_1_1_ELSET',
#  'SOLID_1_1_SOLID_ELSET',
#  'TOP_ELSET'}

# %%
ax2 = amfe.plot3D_submesh(cyclic_left,alpha=1,plot_nodes=False,linewidth=0.1,color='blue')
ax2.set_xlim(bc)
ax2.set_ylim(bc )
ax2.set_zlim(bc)
amfe.plot3D_submesh(cyclic_right,alpha=1,plot_nodes=False,linewidth=0.1,color='orange',ax=ax2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
contact = Cyclic_Contact(cyclic_left,cyclic_right,sector_angle=theta, unit='rad',tol_radius = tol_radius)

# %%
ax3 = amfe.plot3D_submesh(contact.virtual_slave,alpha=1,plot_nodes=False,linewidth=0.1,color='grey')
#bc = np.array([0,300])
ax3.set_xlim(bc)
ax3.set_ylim(bc )
ax3.set_zlim(bc)
amfe.plot3D_submesh(cyclic_left,alpha=1,plot_nodes=False,linewidth=0.1,color='blue',ax=ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# creating a mechanical component
my_comp = amfe.MechanicalSystem()
my_comp.set_mesh_obj(m)
scaling_factor = 1.0E0
rho = 7.86E-9*scaling_factor # kg/mm3
E = 210.0E3 # MPa = N/mm2
my_material = amfe.KirchhoffMaterial(E=E, nu=0.3, rho=rho, plane_stress=False)
my_comp.set_domain('SOLID_1_1_SOLID_ELSET',my_material)

print('Number of nodes is equal to %i' %my_comp.mesh_class.no_of_nodes)
# Out:
# Preallocating the stiffness matrix
# Done preallocating stiffness matrix with 303 elements and 1716 dofs.
# Time taken for preallocation: 0.02 seconds.
# Number of nodes is equal to 572

# %%
n_modes = 10
cyclic_obj = Cyclic_Symmetry_Modal_Analysis(my_comp,
                               dirsub,
                               cyclic_left,
                               cyclic_right,
                               sector_angle=theta,
                               unit='rad',
                               tol_radius = tol_radius, 
                               node_diam_range = (0,3),
                               n_modes=n_modes)

comp_list = cyclic_obj.comp_ND_list
s = cyclic_obj.selector_operator
# Out:
# xyz direction choosen for cyclic symmetry

# %%
from ipywidgets import interact
import mpl_toolkits.mplot3d as a3


def create_sector_list(my_comp,node_diam):
    sector_list = []
    for i in range(n_sector):
        sector_i = create_rotated_component(my_comp,s,sector_id=i, node_id=node_diam, theta=-theta, unit='rad', dimension=3)
        sector_list.append(sector_i)
    return sector_list

def plot_sector_list(sector_list, ax1):
    ax1.clear()
    plot_list = []
    reference = True
    for sector_i in sector_list:
        displacement = sector_i.u_output
        m_i = sector_i.mesh_class
        if reference:
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id, facecolor=0.8*np.array((1,1,1)))    
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, alpha=1,edgecolor='black',linewidth=0.1)   
            collections=[]
            reference = False
        else:
            
            
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id)
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, alpha=1,edgecolor='black',linewidth=0.1)   
            collections = pltmesh.ax.collections
        
        plot_list.append(pltmesh)
        
    return plot_list

node_id_selected = 0
sector_list_0 = create_sector_list(comp_list[0],node_id_selected)
sector_list_1 = create_sector_list(comp_list[1],node_id_selected)
sector_list_2 = create_sector_list(comp_list[2],node_id_selected)

fig0 = plt.figure(figsize=(8,8))
ax0 = fig0.add_subplot(1,1,1,projection='3d')
plt_list_0 = plot_sector_list(sector_list_0, ax0)
plt_list_1 = plot_sector_list(sector_list_1, ax0)
plt_list_2 = plot_sector_list(sector_list_2, ax0)
plt_list_primal = [plt_list_0,plt_list_1,plt_list_2]

ax0.set_xlim(bc)
ax0.set_ylim(bc)
ax0.set_zlim(bc)
@interact(factor=(-1.0,1.0,0.05),mode_id=(0,n_modes,1),node_id_selected=(0,3,1))
def plot2(factor=0.1,mode_id=0,node_id_selected=0):
    
    plt_list_0 = plt_list_primal[node_id_selected]
    collections = []
    for plot_obj in plt_list_0 :
        plot_obj.show(factor=10000*factor,plot_nodes=False,displacement_id=mode_id, collections=collections)
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(FloatSlider(value=0.1, description='factor', max=1.0, min=-1.0, step=0.05), IntSlider(va…

# %%
cyclic_comp = Cyclic_Component(my_comp,
                      dirsub,
                      cyclic_left,
                      cyclic_right,
                      sector_angle=theta,
                      unit='rad',
                      tol_radius = tol_radius)

#P_n_0 = cyclic_comp.build_complex_projection(0)
#P_n_1 = cyclic_comp.build_complex_projection(1)
#P_n_2 = cyclic_comp.build_complex_projection(2)
#P_n_3 = cyclic_comp.build_complex_projection(3)
#P_n_4 = cyclic_comp.build_complex_projection(4)
#P_n_5 = cyclic_comp.build_complex_projection(5)

max_number_of_node_diam = 12
P_n_list = []
for node_diam in range(max_number_of_node_diam+1):
    P_n_list.append(cyclic_comp.build_complex_projection(node_diam))

K_sector, M_sector = cyclic_comp.assemble_sector_operators()
s = cyclic_comp.s
# Out:
# xyz direction choosen for cyclic symmetry
# C:\Users\ge72tih\AppData\Local\Continuum\anaconda3\envs\ndcsi\lib\site-packages\scipy\sparse\compressed.py:746: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %%
P_n_list
# Out:
# [<1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>,
#  <1596x1596 sparse matrix of type '<class 'numpy.complex128'>'
#  	with 1876 stored elements in Compressed Sparse Row format>]

# %%
n_modes = 20
ndofs = cyclic_comp.ndofs
nc = cyclic_comp.nc
dimension = my_comp.mesh_class.no_of_dofs_per_node
no_of_dofs = my_comp.mesh_class.no_of_dofs
fill_perc = 0.2
drop_tol = 1.0E-6
#K_inv = sparse.linalg.inv(K_sector)
#K_pinv = P_n.dot(K_inv).dot(P_n)
#P_n_inv = sparse.csc_matrix(np.linalg.pinv(P_n.toarray()))
#P_n_list = [P_n_0,P_n_1,P_n_2,P_n_3]
res_dict = {}
for i in range(len(P_n_list)):
    
    P_n = P_n_list[i]

    Kp = P_n.conj().T.dot(K_sector.dot(P_n))
    scipy_K_inv = sparse.csc_matrix(np.linalg.pinv(Kp.toarray()))

    
    I = sparse.eye(ndofs)
    
    pre_obj1 = ProjPrecondLinearSys(K_sector,P_n, incomplete=True, fill_factor = int(fill_perc*no_of_dofs), drop_tol=drop_tol )
    pre_obj2 = ProjPrecondLinearSys(K_sector,P_n, incomplete=False )
    pre_obj3 = ProjPrecondLinearSys(K_sector,I, incomplete=True, fill_factor = int(fill_perc*no_of_dofs), drop_tol=drop_tol )
    pre_obj4 = ProjPrecondLinearSys(K_sector,I, incomplete=False )
    #pre_obj5 = ProjPrecondLinearSys(Kp,I, incomplete=False )
    
    #lu = sparse.linalg.splu(K_sector)
    #lui = sparse.linalg.spilu(K_sector)
    #lun = sparse.linalg.splu(Kp)

    precond0 = I
    precond1 = pre_obj1.getLinearOperator()
    precond2 = pre_obj2.getLinearOperator()
    precond3 = pre_obj3.getLinearOperator()
    precond4 = pre_obj4.getLinearOperator()
    #precond5 = pre_obj5.getLinearOperator()
    precond5 = scipy_K_inv

    list_precond = [precond0,
                   precond1,
                   precond2,
                   precond3,
                   precond4,
                   precond5]

    for j in range(len(list_precond)): #
        precond_j = list_precond[j]
        lo_obj = ProjLinearSys(K_sector,M_sector,P_n,precond_j)
        Dp_new = lo_obj.getLinearOperator()
        w2new, v2new = sparse.linalg.eigs(Dp_new, k=n_modes)
        new_id = np.argsort(w2new)[::-1]
        w2new = w2new[new_id]
        v2new = v2new[:,new_id]

        u_vnew = assemble_cyclic_modes(s,v2new,node_id=i,compute_left=False,dimension=dimension)
        comp_i = copy.deepcopy(my_comp)
        comp_i.u_output = []
        comp_i.u_output = list(u_vnew.T)
        local_dict = {}
        local_dict['comp']= comp_i
        local_dict['linearOp'] = lo_obj
        local_dict['TotalLienarOpCall'] = lo_obj.num_iters
        local_dict['AvgLienarOpCall'] = lo_obj.num_iters/lo_obj.solver_counter
        local_dict['eigenvalues'] = 1.0/(w2new.real)
        local_dict['omega'] = np.sqrt(scaling_factor*local_dict['eigenvalues'])
        local_dict['frequency'] = local_dict['omega']/(2.0*np.pi)
        local_dict['SolverCalls'] = lo_obj.solver_counter
        res_dict[i,j] =local_dict

# %%
res_dict
# Out:
# {(0, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef1a6f8d0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef1a6f7b8>,
#   'TotalLienarOpCall': 30938,
#   'AvgLienarOpCall': 491.07936507936506,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683034,  27986.95657032, 145631.70971231, 166169.90942666,
#          194135.53454558, 206194.8521342 , 210024.44224953, 264806.65678776,
#          312927.92814642, 384227.92946466, 414165.76839164, 476014.29186363,
#          612610.56747007, 620314.90141774, 673867.50695468, 681082.19456609,
#          692404.12776358, 732464.51214816, 819388.47365113, 828650.22200953]),
#   'frequency': array([  2881.63343036,   4454.26248026,  23178.00647164,  26446.76247839,
#           30897.62995272,  32816.92995726,  33426.42815413,  42145.28839141,
#           49804.02659601,  61151.77424827,  65916.52929898,  75760.02753249,
#           97500.00000319,  98726.18283419, 107249.34472085, 108397.59791707,
#          110199.53955081, 116575.34774777, 130409.7258941 , 131883.77892701]),
#   'SolverCalls': 63},
#  (0, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef1a6f898>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef1a23898>,
#   'TotalLienarOpCall': 5978,
#   'AvgLienarOpCall': 94.88888888888889,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683034,  27986.95657032, 145631.70971229, 166169.90942661,
#          194135.53454555, 206194.85213418, 210024.44224945, 264806.65678768,
#          312927.92814635, 384227.92946457, 414165.76839156, 476014.29186355,
#          612610.56746994, 620314.90141851, 673867.50695528, 681082.19456641,
#          692404.12776363, 732464.51214814, 819388.4736511 , 828650.22200745]),
#   'frequency': array([  2881.63343036,   4454.26248026,  23178.00647164,  26446.76247838,
#           30897.62995271,  32816.92995726,  33426.42815412,  42145.2883914 ,
#           49804.026596  ,  61151.77424825,  65916.52929897,  75760.02753247,
#           97500.00000317,  98726.18283432, 107249.34472094, 108397.59791712,
#          110199.53955081, 116575.34774777, 130409.7258941 , 131883.77892668]),
#   'SolverCalls': 63},
#  (0, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef1a37d68>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef406fda0>,
#   'TotalLienarOpCall': 1887,
#   'AvgLienarOpCall': 29.952380952380953,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683034,  27986.95657032, 145631.70971231, 166169.90942665,
#          194135.53454558, 206194.8521342 , 210024.44224955, 264806.65678774,
#          312927.92814642, 384227.92946464, 414165.76839164, 476014.29186361,
#          612610.56746984, 620314.9014178 , 673867.50695504, 681082.19456612,
#          692404.1277636 , 732464.51214814, 819388.47365106, 828650.222008  ]),
#   'frequency': array([  2881.63343036,   4454.26248026,  23178.00647164,  26446.76247838,
#           30897.62995272,  32816.92995726,  33426.42815413,  42145.28839141,
#           49804.02659601,  61151.77424826,  65916.52929898,  75760.02753248,
#           97500.00000316,  98726.1828342 , 107249.34472091, 108397.59791707,
#          110199.53955081, 116575.34774777, 130409.72589409, 131883.77892677]),
#   'SolverCalls': 63},
#  (0, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef40c6978>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef40ca2e8>,
#   'TotalLienarOpCall': 6007,
#   'AvgLienarOpCall': 95.34920634920636,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683034,  27986.95657032, 145631.70971227, 166169.90942656,
#          194135.53454557, 206194.85213421, 210024.44224951, 264806.65678772,
#          312927.92814639, 384227.92946462, 414165.7683915 , 476014.29186346,
#          612610.56746965, 620314.90141798, 673867.50695436, 681082.19456598,
#          692404.12776331, 732464.51214827, 819388.47365168, 828650.22200871]),
#   'frequency': array([  2881.63343036,   4454.26248026,  23178.00647163,  26446.76247837,
#           30897.62995272,  32816.92995726,  33426.42815413,  42145.2883914 ,
#           49804.026596  ,  61151.77424826,  65916.52929896,  75760.02753246,
#           97500.00000313,  98726.18283423, 107249.3447208 , 108397.59791705,
#          110199.53955076, 116575.34774779, 130409.72589419, 131883.77892688]),
#   'SolverCalls': 63},
#  (0, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef40c67b8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef41147f0>,
#   'TotalLienarOpCall': 1885,
#   'AvgLienarOpCall': 29.92063492063492,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683034,  27986.95657032, 145631.70971231, 166169.90942666,
#          194135.53454555, 206194.85213419, 210024.44224953, 264806.65678774,
#          312927.92814642, 384227.92946466, 414165.76839165, 476014.29186362,
#          612610.56746986, 620314.90141774, 673867.50695524, 681082.19456565,
#          692404.1277636 , 732464.51214814, 819388.47365104, 828650.22200795]),
#   'frequency': array([  2881.63343036,   4454.26248026,  23178.00647164,  26446.76247839,
#           30897.62995271,  32816.92995726,  33426.42815413,  42145.28839141,
#           49804.02659601,  61151.77424827,  65916.52929898,  75760.02753248,
#           97500.00000316,  98726.18283419, 107249.34472094, 108397.597917  ,
#          110199.53955081, 116575.34774777, 130409.72589409, 131883.77892676]),
#   'SolverCalls': 63},
#  (0, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29ef40f6cc0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29ef4148cf8>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([3.27821327e+08, 7.83269738e+08, 2.12085949e+10, 2.76124388e+10,
#          3.76886058e+10, 4.25163170e+10, 4.41102663e+10, 7.01225655e+10,
#          9.79238882e+10, 1.47631102e+11, 1.71533284e+11, 2.26589606e+11,
#          3.75291707e+11, 3.84790577e+11, 4.54097417e+11, 4.63872956e+11,
#          4.79423476e+11, 5.36504262e+11, 6.71397471e+11, 6.86661190e+11]),
#   'omega': array([ 18105.83683033,  27986.95657035, 145631.70971268, 166169.90942691,
#          194135.53454588, 206194.85213469, 210024.44224992, 264806.6567883 ,
#          312927.92814692, 384227.92946522, 414165.76839206, 476014.29186446,
#          612610.56747119, 620314.90141892, 673867.50695527, 681082.19456716,
#          692404.12776464, 732464.5121492 , 819388.47365203, 828650.22200917]),
#   'frequency': array([  2881.63343036,   4454.26248027,  23178.0064717 ,  26446.76247843,
#           30897.62995276,  32816.92995734,  33426.42815419,  42145.2883915 ,
#           49804.02659609,  61151.77424835,  65916.52929905,  75760.02753262,
#           97500.00000337,  98726.18283438, 107249.34472094, 108397.59791724,
#          110199.53955097, 116575.34774794, 130409.72589424, 131883.77892696]),
#   'SolverCalls': 63},
#  (1, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88189a90>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e881899b0>,
#   'TotalLienarOpCall': 30590,
#   'AvgLienarOpCall': 485.55555555555554,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025232,  76043.95237125, 138652.07018711, 168997.02455129,
#          177182.71136094, 208005.68084887, 244549.67224465, 270447.5248222 ,
#          312524.49161484, 391018.45107408, 413827.54571016, 471421.87148436,
#          603714.42604201, 610992.10239799, 633931.20814855, 663571.38448852,
#          738290.01792275, 750820.99288799, 779884.37473676, 819983.18683813]),
#   'frequency': array([  2875.62587589,  12102.77091213,  22067.1623402 ,  26896.71182516,
#           28199.50434352,  33105.13229829,  38921.28916924,  43043.06042242,
#           49739.81767778,  62232.51932858,  65862.69948736,  75029.12112837,
#           96084.13512047,  97242.41328675, 100893.28535706, 105610.66593568,
#          117502.50578781, 119496.87239529, 124122.45327949, 130504.37743753]),
#   'SolverCalls': 63},
#  (1, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88189a58>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e881aea58>,
#   'TotalLienarOpCall': 10522,
#   'AvgLienarOpCall': 167.015873015873,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025231,  76043.95237124, 138652.07018713, 168997.02455124,
#          177182.71136093, 208005.68084884, 244549.6722447 , 270447.52482209,
#          312524.49161481, 391018.45107395, 413827.54570994, 471421.87148427,
#          603714.42604089, 610992.10239778, 633931.20814943, 663571.38448788,
#          738290.01792284, 750820.99288807, 779884.37473722, 819983.18683793]),
#   'frequency': array([  2875.62587589,  12102.77091213,  22067.16234021,  26896.71182515,
#           28199.50434352,  33105.13229829,  38921.28916925,  43043.0604224 ,
#           49739.81767778,  62232.51932855,  65862.69948732,  75029.12112835,
#           96084.13512029,  97242.41328672, 100893.2853572 , 105610.66593558,
#          117502.50578782, 119496.8723953 , 124122.45327956, 130504.3774375 ]),
#   'SolverCalls': 63},
#  (1, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e881c0f28>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e881e2f60>,
#   'TotalLienarOpCall': 2113,
#   'AvgLienarOpCall': 33.53968253968254,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025231,  76043.95237125, 138652.07018711, 168997.02455128,
#          177182.71136094, 208005.68084886, 244549.67224463, 270447.5248222 ,
#          312524.49161484, 391018.45107415, 413827.54571022, 471421.87148437,
#          603714.4260419 , 610992.10239802, 633931.20814847, 663571.38448861,
#          738290.01792284, 750820.99288798, 779884.37473688, 819983.18683831]),
#   'frequency': array([  2875.62587589,  12102.77091213,  22067.1623402 ,  26896.71182516,
#           28199.50434352,  33105.13229829,  38921.28916924,  43043.06042242,
#           49739.81767778,  62232.51932859,  65862.69948737,  75029.12112837,
#           96084.13512045,  97242.41328675, 100893.28535705, 105610.66593569,
#          117502.50578782, 119496.87239529, 124122.45327951, 130504.37743756]),
#   'SolverCalls': 63},
#  (1, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8820c470>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e882344a8>,
#   'TotalLienarOpCall': 10493,
#   'AvgLienarOpCall': 166.55555555555554,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025231,  76043.95237123, 138652.07018708, 168997.02455129,
#          177182.71136095, 208005.68084885, 244549.6722446 , 270447.52482212,
#          312524.49161489, 391018.45107406, 413827.54570996, 471421.87148427,
#          603714.42604207, 610992.10239786, 633931.20814803, 663571.38448843,
#          738290.01792245, 750820.99288737, 779884.37473641, 819983.18683842]),
#   'frequency': array([  2875.62587589,  12102.77091213,  22067.1623402 ,  26896.71182516,
#           28199.50434352,  33105.13229829,  38921.28916923,  43043.06042241,
#           49739.81767779,  62232.51932857,  65862.69948733,  75029.12112835,
#           96084.13512048,  97242.41328673, 100893.28535698, 105610.66593567,
#          117502.50578776, 119496.87239519, 124122.45327943, 130504.37743758]),
#   'SolverCalls': 63},
#  (1, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88248978>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e8826f9b0>,
#   'TotalLienarOpCall': 2120,
#   'AvgLienarOpCall': 33.65079365079365,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025232,  76043.95237125, 138652.07018711, 168997.02455129,
#          177182.71136093, 208005.68084886, 244549.67224463, 270447.5248222 ,
#          312524.49161484, 391018.45107393, 413827.54571015, 471421.87148433,
#          603714.42604189, 610992.10239802, 633931.2081484 , 663571.38448859,
#          738290.01792282, 750820.99288759, 779884.37473674, 819983.18683819]),
#   'frequency': array([  2875.62587589,  12102.77091213,  22067.1623402 ,  26896.71182516,
#           28199.50434352,  33105.13229829,  38921.28916924,  43043.06042242,
#           49739.81767778,  62232.51932855,  65862.69948736,  75029.12112836,
#           96084.13512045,  97242.41328675, 100893.28535704, 105610.66593569,
#          117502.50578782, 119496.87239523, 124122.45327948, 130504.37743754]),
#   'SolverCalls': 63},
#  (1, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e882ce550>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e882a8eb8>,
#   'TotalLienarOpCall': 64,
#   'AvgLienarOpCall': 1.0158730158730158,
#   'eigenvalues': array([3.26455885e+08, 5.78268269e+09, 1.92243966e+10, 2.85599943e+10,
#          3.13937132e+10, 4.32663633e+10, 5.98045422e+10, 7.31418637e+10,
#          9.76715579e+10, 1.52895429e+11, 1.71253238e+11, 2.22238581e+11,
#          3.64471108e+11, 3.73311349e+11, 4.01868777e+11, 4.40326982e+11,
#          5.45072151e+11, 5.63732163e+11, 6.08219638e+11, 6.72372427e+11]),
#   'omega': array([ 18068.09025232,  76043.95237122, 138652.07018691, 168997.02455114,
#          177182.71136086, 208005.68084874, 244549.67224431, 270447.52482209,
#          312524.49161481, 391018.45107389, 413827.54570994, 471421.87148365,
#          603714.42604139, 610992.10239754, 633931.20814814, 663571.38448792,
#          738290.01792209, 750820.992887  , 779884.37473592, 819983.18683735]),
#   'frequency': array([  2875.62587589,  12102.77091212,  22067.16234017,  26896.71182514,
#           28199.50434351,  33105.13229827,  38921.28916918,  43043.0604224 ,
#           49739.81767778,  62232.51932855,  65862.69948732,  75029.12112826,
#           96084.13512037,  97242.41328668, 100893.28535699, 105610.66593559,
#          117502.5057877 , 119496.87239513, 124122.45327935, 130504.37743741]),
#   'SolverCalls': 63},
#  (2, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8830fdd8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e8830fb70>,
#   'TotalLienarOpCall': 30304,
#   'AvgLienarOpCall': 481.015873015873,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872454, 103282.38916865, 110127.7529541 , 166874.9994868 ,
#          198968.60378411, 230957.586355  , 287047.22835324, 291846.86990562,
#          311573.23517879, 409117.52806866, 412751.01438081, 460768.4782782 ,
#          553783.39264362, 584319.3198662 , 616909.58817415, 627489.11550167,
#          747248.10346592, 756014.8897029 , 773664.11893748, 818223.98600908]),
#   'frequency': array([  3363.83501222,  16437.90277053,  17527.37625425,  26558.98104678,
#           31666.83681233,  36758.04151297,  45684.98529325,  46448.87197138,
#           49588.42051384,  65113.07689766,  65691.3642049 ,  73333.58093891,
#           88137.36434143,  92997.3081008 ,  98184.2103987 ,  99867.99446845,
#          118928.22938265, 120323.50674729, 123132.46882174, 130224.3919297 ]),
#   'SolverCalls': 63},
#  (2, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8830fc18>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88766c18>,
#   'TotalLienarOpCall': 11001,
#   'AvgLienarOpCall': 174.61904761904762,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872454, 103282.38916856, 110127.75295405, 166874.99948664,
#          198968.60378396, 230957.5863548 , 287047.22835298, 291846.86990537,
#          311573.23517852, 409117.52806825, 412751.01438057, 460768.47827775,
#          553783.3926431 , 584319.31986494, 616909.58817308, 627489.11550024,
#          747248.10346451, 756014.88970233, 773664.11893622, 818223.98600795]),
#   'frequency': array([  3363.83501222,  16437.90277052,  17527.37625424,  26558.98104676,
#           31666.83681231,  36758.04151294,  45684.98529321,  46448.87197134,
#           49588.42051379,  65113.0768976 ,  65691.36420486,  73333.58093884,
#           88137.36434135,  92997.3081006 ,  98184.21039853,  99867.99446822,
#          118928.22938242, 120323.5067472 , 123132.46882153, 130224.39192952]),
#   'SolverCalls': 63},
#  (2, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8835a7f0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88344160>,
#   'TotalLienarOpCall': 2127,
#   'AvgLienarOpCall': 33.76190476190476,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872454, 103282.38916865, 110127.7529541 , 166874.99948679,
#          198968.60378413, 230957.58635497, 287047.22835326, 291846.86990561,
#          311573.23517879, 409117.52806872, 412751.01438083, 460768.4782782 ,
#          553783.39264352, 584319.31986623, 616909.58817421, 627489.11550179,
#          747248.10346605, 756014.88970295, 773664.11893752, 818223.98600919]),
#   'frequency': array([  3363.83501222,  16437.90277053,  17527.37625425,  26558.98104678,
#           31666.83681234,  36758.04151297,  45684.98529325,  46448.87197137,
#           49588.42051384,  65113.07689767,  65691.3642049 ,  73333.58093891,
#           88137.36434142,  92997.3081008 ,  98184.21039871,  99867.99446847,
#          118928.22938267, 120323.5067473 , 123132.46882174, 130224.39192972]),
#   'SolverCalls': 63},
#  (2, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8835a630>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88383668>,
#   'TotalLienarOpCall': 11040,
#   'AvgLienarOpCall': 175.23809523809524,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872454, 103282.38916858, 110127.75295406, 166874.99948672,
#          198968.60378389, 230957.58635471, 287047.22835283, 291846.86990534,
#          311573.23517855, 409117.5280684 , 412751.01438012, 460768.47827775,
#          553783.39264235, 584319.31986533, 616909.58817284, 627489.11550002,
#          747248.10346429, 756014.88970231, 773664.11893654, 818223.98600843]),
#   'frequency': array([  3363.83501222,  16437.90277052,  17527.37625424,  26558.98104677,
#           31666.8368123 ,  36758.04151293,  45684.98529318,  46448.87197133,
#           49588.4205138 ,  65113.07689762,  65691.36420479,  73333.58093884,
#           88137.36434123,  92997.30810066,  98184.21039849,  99867.99446819,
#          118928.22938239, 120323.5067472 , 123132.46882159, 130224.3919296 ]),
#   'SolverCalls': 63},
#  (2, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88396b38>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e883c2b70>,
#   'TotalLienarOpCall': 2128,
#   'AvgLienarOpCall': 33.77777777777778,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872453, 103282.38916865, 110127.7529541 , 166874.99948679,
#          198968.60378413, 230957.58635498, 287047.22835318, 291846.86990564,
#          311573.23517878, 409117.52806854, 412751.01438083, 460768.47827813,
#          553783.39264361, 584319.31986623, 616909.58817419, 627489.11550216,
#          747248.1034657 , 756014.88970303, 773664.11893748, 818223.98600912]),
#   'frequency': array([  3363.83501222,  16437.90277053,  17527.37625425,  26558.98104678,
#           31666.83681234,  36758.04151297,  45684.98529324,  46448.87197138,
#           49588.42051384,  65113.07689765,  65691.3642049 ,  73333.58093889,
#           88137.36434143,  92997.3081008 ,  98184.21039871,  99867.99446853,
#          118928.22938261, 120323.50674731, 123132.46882174, 130224.39192971]),
#   'SolverCalls': 63},
#  (2, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88425748>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e8840f0b8>,
#   'TotalLienarOpCall': 63,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([4.46713533e+08, 1.06672519e+10, 1.21281220e+10, 2.78472655e+10,
#          3.95885053e+10, 5.33414067e+10, 8.23961113e+10, 8.51745955e+10,
#          9.70778809e+10, 1.67377152e+11, 1.70363400e+11, 2.12307591e+11,
#          3.06676046e+11, 3.41429068e+11, 3.80577440e+11, 3.93742590e+11,
#          5.58379728e+11, 5.71558513e+11, 5.98556169e+11, 6.69490491e+11]),
#   'omega': array([ 21135.59872453, 103282.38916867, 110127.75295413, 166874.99948691,
#          198968.6037842 , 230957.58635514, 287047.2283534 , 291846.86990579,
#          311573.23517893, 409117.52806899, 412751.01438112, 460768.47827853,
#          553783.39264402, 584319.31986665, 616909.58817442, 627489.1155021 ,
#          747248.10346648, 756014.88970353, 773664.11893808, 818223.98600965]),
#   'frequency': array([  3363.83501222,  16437.90277053,  17527.37625425,  26558.9810468 ,
#           31666.83681235,  36758.04151299,  45684.98529327,  46448.8719714 ,
#           49588.42051386,  65113.07689772,  65691.36420495,  73333.58093896,
#           88137.3643415 ,  92997.30810087,  98184.21039874,  99867.99446852,
#          118928.22938273, 120323.50674739, 123132.46882183, 130224.39192979]),
#   'SolverCalls': 63},
#  (3, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88461f98>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88461d30>,
#   'TotalLienarOpCall': 24652,
#   'AvgLienarOpCall': 474.0769230769231,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644185,
#          196298.79735841, 269724.33028952, 310604.3847073 , 338030.84220903,
#          340145.11500507, 410345.80857884, 430905.98299477, 450468.19220603,
#          502349.57997583, 538693.42871095, 551631.02712235, 631080.050178  ,
#          745321.56591154, 748351.99563502, 785641.86540425, 815854.13484561]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945508,
#           54135.77642162,  65308.56381236,  68580.81720149,  71694.23949526,
#           79951.41881329,  85735.72199047,  87794.80472938, 100439.50947251,
#          118621.61140781, 119103.919278  , 125038.78637902, 129847.21840264]),
#   'SolverCalls': 52},
#  (3, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e88461a58>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88481dd8>,
#   'TotalLienarOpCall': 12700,
#   'AvgLienarOpCall': 201.5873015873016,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788091, 104259.48276368, 172027.42644176,
#          196298.79735833, 269724.33028935, 310604.38470714, 338030.84220883,
#          340145.11500487, 410345.80857846, 430905.98299473, 450468.19220563,
#          502349.5799752 , 538693.42871045, 551631.02712196, 631080.05017628,
#          745321.56591058, 748351.99563401, 785641.86540267, 815854.13484419]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204604,  27379.01526558,
#           31241.92392257,  42927.9604377 ,  49434.22317216,  53799.27945505,
#           54135.77642159,  65308.5638123 ,  68580.81720148,  71694.2394952 ,
#           79951.41881319,  85735.72199039,  87794.80472932, 100439.50947224,
#          118621.61140766, 119103.91927784, 125038.78637877, 129847.21840241]),
#   'SolverCalls': 63},
#  (3, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e887df9b0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e887ca320>,
#   'TotalLienarOpCall': 2159,
#   'AvgLienarOpCall': 34.26984126984127,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644184,
#          196298.79735841, 269724.33028954, 310604.3847073 , 338030.84220897,
#          340145.11500507, 410345.80857885, 430905.98299468, 450468.192206  ,
#          502349.57997595, 538693.42871107, 551631.02712242, 631080.05017782,
#          745321.56591161, 748351.99563469, 785641.86540372, 815854.13484508]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945507,
#           54135.77642162,  65308.56381236,  68580.81720148,  71694.23949526,
#           79951.41881331,  85735.72199049,  87794.80472939, 100439.50947248,
#          118621.61140782, 119103.91927795, 125038.78637894, 129847.21840256]),
#   'SolverCalls': 63},
#  (3, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e887df7f0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88808828>,
#   'TotalLienarOpCall': 12668,
#   'AvgLienarOpCall': 201.0793650793651,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.7478809 , 104259.48276368, 172027.42644177,
#          196298.79735832, 269724.33028947, 310604.38470712, 338030.84220893,
#          340145.11500484, 410345.80857843, 430905.98299445, 450468.19220569,
#          502349.57997539, 538693.42871045, 551631.02712193, 631080.05017643,
#          745321.56591084, 748351.99563361, 785641.86540303, 815854.13484502]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204604,  27379.01526559,
#           31241.92392257,  42927.96043772,  49434.22317215,  53799.27945507,
#           54135.77642158,  65308.5638123 ,  68580.81720144,  71694.2394952 ,
#           79951.41881322,  85735.72199039,  87794.80472931, 100439.50947226,
#          118621.6114077 , 119103.91927777, 125038.78637883, 129847.21840255]),
#   'SolverCalls': 63},
#  (3, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e8881acf8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e88845d30>,
#   'TotalLienarOpCall': 2160,
#   'AvgLienarOpCall': 34.285714285714285,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644184,
#          196298.79735842, 269724.33028954, 310604.38470729, 338030.84220912,
#          340145.11500507, 410345.80857883, 430905.98299489, 450468.19220602,
#          502349.57997599, 538693.42871105, 551631.02712242, 631080.05017789,
#          745321.56591174, 748351.99563473, 785641.86540373, 815854.13484561]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.2794551 ,
#           54135.77642162,  65308.56381236,  68580.81720151,  71694.23949526,
#           79951.41881332,  85735.72199048,  87794.80472939, 100439.50947249,
#          118621.61140785, 119103.91927795, 125038.78637894, 129847.21840264]),
#   'SolverCalls': 63},
#  (3, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e93526908>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e93513278>,
#   'TotalLienarOpCall': 63,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788091, 104259.48276371, 172027.42644182,
#          196298.79735839, 269724.33028951, 310604.38470727, 338030.84220896,
#          340145.11500499, 410345.80857878, 430905.98299473, 450468.19220594,
#          502349.57997575, 538693.42871096, 551631.02712233, 631080.05017785,
#          745321.56591147, 748351.99563462, 785641.86540367, 815854.13484541]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.01526559,
#           31241.92392258,  42927.96043773,  49434.22317218,  53799.27945507,
#           54135.77642161,  65308.56381235,  68580.81720148,  71694.23949525,
#           79951.41881328,  85735.72199047,  87794.80472938, 100439.50947249,
#          118621.6114078 , 119103.91927793, 125038.78637893, 129847.21840261]),
#   'SolverCalls': 63},
#  (4, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e93569fd0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e93569ef0>,
#   'TotalLienarOpCall': 29694,
#   'AvgLienarOpCall': 471.3333333333333,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658375,
#          195025.2976586 , 276755.98752015, 310231.78214405, 364313.56103714,
#          406612.51983453, 414402.77135412, 419462.56006962, 446094.86726863,
#          477204.77717023, 487072.7023167 , 533802.77837734, 633085.34089935,
#          739408.86818781, 747094.58544992, 804807.45422403, 815062.92374851]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163243,  57982.30407447,
#           64714.39245472,  65954.24949199,  66759.53987706,  70998.20321372,
#           75949.49915371,  77520.02821883,  84957.35081494, 100758.66140315,
#          117680.57633807, 118903.79623154, 128089.08457696, 129721.29324551]),
#   'SolverCalls': 63},
#  (4, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e93569c18>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e9358bf98>,
#   'TotalLienarOpCall': 7208,
#   'AvgLienarOpCall': 138.6153846153846,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779869, 174505.28658372,
#          195025.29765856, 276755.98752004, 310231.78214393, 364313.56103722,
#          406612.51983431, 414402.77135391, 419462.5600695 , 446094.86726868,
#          477204.77716964, 487072.70231639, 533802.77837737, 633085.34089923,
#          739408.86818693, 747094.58544956, 804807.45422398, 815062.92374671]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015033,  44047.08344409,  49374.92163241,  57982.30407448,
#           64714.39245468,  65954.24949195,  66759.53987704,  70998.20321373,
#           75949.49915362,  77520.02821878,  84957.35081495, 100758.66140313,
#          117680.57633793, 118903.79623149, 128089.08457695, 129721.29324522]),
#   'SolverCalls': 52},
#  (4, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e935b04e0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e935dd4e0>,
#   'TotalLienarOpCall': 1794,
#   'AvgLienarOpCall': 34.5,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658374,
#          195025.2976586 , 276755.98752016, 310231.78214403, 364313.56103699,
#          406612.51983455, 414402.77135409, 419462.56006962, 446094.86726864,
#          477204.77717013, 487072.7023168 , 533802.7783774 , 633085.34089915,
#          739408.86818757, 747094.58545014, 804807.45422397, 815062.92374856]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015034,  44047.08344411,  49374.92163243,  57982.30407445,
#           64714.39245472,  65954.24949198,  66759.53987706,  70998.20321373,
#           75949.49915369,  77520.02821885,  84957.35081495, 100758.66140312,
#          117680.57633803, 118903.79623158, 128089.08457695, 129721.29324552]),
#   'SolverCalls': 52},
#  (4, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e935f39e8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e9361c9e8>,
#   'TotalLienarOpCall': 7244,
#   'AvgLienarOpCall': 139.30769230769232,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876721, 102809.06779868, 174505.28658364,
#          195025.29765847, 276755.98751992, 310231.78214405, 364313.56103705,
#          406612.51983412, 414402.77135412, 419462.5600697 , 446094.86726852,
#          477204.77717019, 487072.70231652, 533802.77837729, 633085.34089958,
#          739408.86818755, 747094.58544948, 804807.45422327, 815062.92374865]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895545,
#           31039.24015031,  44047.08344407,  49374.92163243,  57982.30407446,
#           64714.39245465,  65954.24949199,  66759.53987707,  70998.20321371,
#           75949.4991537 ,  77520.0282188 ,  84957.35081493, 100758.66140319,
#          117680.57633803, 118903.79623147, 128089.08457684, 129721.29324553]),
#   'SolverCalls': 52},
#  (4, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e9362def0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e9365aef0>,
#   'TotalLienarOpCall': 2187,
#   'AvgLienarOpCall': 34.714285714285715,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658375,
#          195025.29765862, 276755.98752015, 310231.78214412, 364313.56103716,
#          406612.51983452, 414402.77135413, 419462.56006962, 446094.86726858,
#          477204.77717017, 487072.70231684, 533802.77837739, 633085.34089914,
#          739408.86818755, 747094.58545013, 804807.45422397, 815062.92374856]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015034,  44047.08344411,  49374.92163244,  57982.30407448,
#           64714.39245472,  65954.24949199,  66759.53987706,  70998.20321372,
#           75949.4991537 ,  77520.02821885,  84957.35081495, 100758.66140312,
#          117680.57633803, 118903.79623158, 128089.08457695, 129721.29324552]),
#   'SolverCalls': 63},
#  (4, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e9367d400>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e936a8438>,
#   'TotalLienarOpCall': 52,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876723, 102809.06779864, 174505.28658374,
#          195025.29765858, 276755.98752013, 310231.78214404, 364313.56103711,
#          406612.5198345 , 414402.77135409, 419462.5600696 , 446094.8672686 ,
#          477204.77717023, 487072.70231678, 533802.77837733, 633085.34089925,
#          739408.86818752, 747094.58545004, 804807.45422394, 815062.92374846]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133482,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163243,  57982.30407447,
#           64714.39245471,  65954.24949198,  66759.53987706,  70998.20321372,
#           75949.49915371,  77520.02821884,  84957.35081494, 100758.66140313,
#          117680.57633803, 118903.79623156, 128089.08457694, 129721.2932455 ]),
#   'SolverCalls': 52},
#  (5, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e936fadd8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e94c8d0f0>,
#   'TotalLienarOpCall': 24652,
#   'AvgLienarOpCall': 474.0769230769231,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644185,
#          196298.79735841, 269724.33028952, 310604.3847073 , 338030.84220903,
#          340145.11500506, 410345.80857885, 430905.98299477, 450468.19220601,
#          502349.57997581, 538693.42871104, 551631.02712236, 631080.05017792,
#          745321.56591156, 748351.99563492, 785641.86540418, 815854.1348456 ]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945508,
#           54135.77642162,  65308.56381236,  68580.81720149,  71694.23949526,
#           79951.41881329,  85735.72199048,  87794.80472938, 100439.5094725 ,
#          118621.61140782, 119103.91927798, 125038.78637901, 129847.21840264]),
#   'SolverCalls': 52},
#  (5, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e94c8d160>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e94ca0198>,
#   'TotalLienarOpCall': 12641,
#   'AvgLienarOpCall': 200.65079365079364,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.7478809 , 104259.48276368, 172027.42644173,
#          196298.79735831, 269724.33028953, 310604.38470709, 338030.84220884,
#          340145.1150049 , 410345.80857846, 430905.98299457, 450468.19220573,
#          502349.57997523, 538693.4287106 , 551631.02712199, 631080.0501764 ,
#          745321.56591144, 748351.99563361, 785641.86540331, 815854.13484447]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204604,  27379.01526558,
#           31241.92392257,  42927.96043773,  49434.22317215,  53799.27945505,
#           54135.77642159,  65308.5638123 ,  68580.81720146,  71694.23949521,
#           79951.4188132 ,  85735.72199041,  87794.80472932, 100439.50947226,
#          118621.6114078 , 119103.91927777, 125038.78637887, 129847.21840246]),
#   'SolverCalls': 63},
#  (5, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e94cb8668>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e948a36a0>,
#   'TotalLienarOpCall': 1791,
#   'AvgLienarOpCall': 34.44230769230769,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644184,
#          196298.79735842, 269724.33028953, 310604.38470731, 338030.84220911,
#          340145.11500508, 410345.80857885, 430905.98299467, 450468.19220599,
#          502349.57997576, 538693.42871105, 551631.02712246, 631080.05017786,
#          745321.56591168, 748351.99563484, 785641.86540376, 815854.13484546]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317219,  53799.2794551 ,
#           54135.77642162,  65308.56381237,  68580.81720147,  71694.23949525,
#           79951.41881328,  85735.72199048,  87794.8047294 , 100439.50947249,
#          118621.61140784, 119103.91927797, 125038.78637895, 129847.21840262]),
#   'SolverCalls': 52},
#  (5, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29e948b6ba8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29e948b6898>,
#   'TotalLienarOpCall': 10530,
#   'AvgLienarOpCall': 202.5,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788089, 104259.48276366, 172027.42644173,
#          196298.79735832, 269724.33028942, 310604.38470701, 338030.8422088 ,
#          340145.11500492, 410345.80857864, 430905.98299446, 450468.19220558,
#          502349.57997536, 538693.42871029, 551631.02712125, 631080.05017715,
#          745321.56591006, 748351.9956338 , 785641.86540308, 815854.13484452]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204604,  27379.01526558,
#           31241.92392257,  42927.96043771,  49434.22317214,  53799.27945505,
#           54135.77642159,  65308.56381233,  68580.81720144,  71694.23949519,
#           79951.41881322,  85735.72199036,  87794.80472921, 100439.50947238,
# ...
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945508,
#           54135.77642162,  65308.56381236,  68580.81720149,  71694.23949525,
#           79951.41881329,  85735.72199047,  87794.80472938, 100439.50947251,
#          118621.61140781, 119103.91927798, 125038.78637898, 129847.21840265]),
#   'SolverCalls': 52},
#  (11, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f4515c8d0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f45183c50>,
#   'TotalLienarOpCall': 12644,
#   'AvgLienarOpCall': 200.6984126984127,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.7478809 , 104259.48276369, 172027.42644178,
#          196298.79735831, 269724.33028946, 310604.38470701, 338030.84220879,
#          340145.11500485, 410345.8085786 , 430905.98299468, 450468.19220583,
#          502349.57997552, 538693.42871008, 551631.02712183, 631080.05017798,
#          745321.56591044, 748351.99563384, 785641.86540268, 815854.13484403]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204605,  27379.01526559,
#           31241.92392257,  42927.96043772,  49434.22317214,  53799.27945504,
#           54135.77642158,  65308.56381232,  68580.81720147,  71694.23949523,
#           79951.41881324,  85735.72199033,  87794.8047293 , 100439.50947251,
#          118621.61140764, 119103.91927781, 125038.78637877, 129847.21840239]),
#   'SolverCalls': 63},
#  (11, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f451e6828>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f451cd198>,
#   'TotalLienarOpCall': 1777,
#   'AvgLienarOpCall': 34.17307692307692,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644184,
#          196298.79735843, 269724.33028953, 310604.3847073 , 338030.84220899,
#          340145.11500508, 410345.80857885, 430905.98299466, 450468.19220598,
#          502349.57997596, 538693.42871105, 551631.02712229, 631080.05017787,
#          745321.5659117 , 748351.99563467, 785641.86540374, 815854.13484523]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945508,
#           54135.77642162,  65308.56381236,  68580.81720147,  71694.23949525,
#           79951.41881331,  85735.72199049,  87794.80472937, 100439.50947249,
#          118621.61140784, 119103.91927794, 125038.78637894, 129847.21840258]),
#   'SolverCalls': 52},
#  (11, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f451e66a0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f996f06a0>,
#   'TotalLienarOpCall': 12714,
#   'AvgLienarOpCall': 201.8095238095238,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.7478809 , 104259.48276366, 172027.42644175,
#          196298.79735833, 269724.33028941, 310604.384707  , 338030.84220867,
#          340145.11500461, 410345.80857859, 430905.98299471, 450468.1922057 ,
#          502349.57997541, 538693.42871047, 551631.02712194, 631080.05017656,
#          745321.56591085, 748351.995634  , 785641.8654034 , 815854.13484447]),
#   'frequency': array([  5153.9911209 ,  12598.66516915,  16593.41204604,  27379.01526558,
#           31241.92392257,  42927.96043771,  49434.22317214,  53799.27945503,
#           54135.77642155,  65308.56381232,  68580.81720148,  71694.23949521,
#           79951.41881322,  85735.72199039,  87794.80472932, 100439.50947228,
#          118621.6114077 , 119103.91927784, 125038.78637889, 129847.21840246]),
#   'SolverCalls': 63},
#  (11, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f99704b70>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f99730ba8>,
#   'TotalLienarOpCall': 1784,
#   'AvgLienarOpCall': 34.30769230769231,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788092, 104259.48276371, 172027.42644185,
#          196298.79735843, 269724.33028954, 310604.38470732, 338030.84220917,
#          340145.1150051 , 410345.80857885, 430905.98299465, 450468.19220603,
#          502349.57997558, 538693.42871102, 551631.02712241, 631080.05017784,
#          745321.56591168, 748351.99563478, 785641.86540366, 815854.13484549]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317219,  53799.27945511,
#           54135.77642162,  65308.56381237,  68580.81720147,  71694.23949526,
#           79951.41881325,  85735.72199048,  87794.80472939, 100439.50947248,
#          118621.61140784, 119103.91927796, 125038.78637893, 129847.21840262]),
#   'SolverCalls': 52},
#  (11, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f9978e780>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f9977b0f0>,
#   'TotalLienarOpCall': 52,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([1.04868986e+09, 6.26626568e+09, 1.08700397e+10, 2.95934354e+10,
#          3.85332178e+10, 7.27512144e+10, 9.64750838e+10, 1.14264850e+11,
#          1.15698699e+11, 1.68383683e+11, 1.85679966e+11, 2.02921592e+11,
#          2.52355101e+11, 2.90190610e+11, 3.04296790e+11, 3.98262030e+11,
#          5.55504237e+11, 5.60030709e+11, 6.17233141e+11, 6.65617969e+11]),
#   'omega': array([ 32383.4812842 ,  79159.74788091, 104259.48276371, 172027.42644184,
#          196298.79735842, 269724.33028954, 310604.3847073 , 338030.84220906,
#          340145.11500507, 410345.80857885, 430905.98299477, 450468.192206  ,
#          502349.57997584, 538693.42871104, 551631.0271224 , 631080.05017798,
#          745321.56591163, 748351.99563478, 785641.86540382, 815854.13484557]),
#   'frequency': array([  5153.9911209 ,  12598.66516916,  16593.41204605,  27379.0152656 ,
#           31241.92392259,  42927.96043773,  49434.22317218,  53799.27945509,
#           54135.77642162,  65308.56381236,  68580.81720149,  71694.23949525,
#           79951.41881329,  85735.72199048,  87794.80472939, 100439.50947251,
#          118621.61140783, 119103.91927796, 125038.78637896, 129847.21840263]),
#   'SolverCalls': 52},
#  (12, 0): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f997cffd0>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29f997cfd68>,
#   'TotalLienarOpCall': 24509,
#   'AvgLienarOpCall': 471.3269230769231,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658375,
#          195025.2976586 , 276755.98752015, 310231.78214405, 364313.56103714,
#          406612.51983455, 414402.7713541 , 419462.56006961, 446094.86726865,
#          477204.77717024, 487072.70231678, 533802.77837733, 633085.34089935,
#          739408.86818791, 747094.58544982, 804807.45422423, 815062.9237484 ]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163243,  57982.30407447,
#           64714.39245472,  65954.24949199,  66759.53987706,  70998.20321373,
#           75949.49915371,  77520.02821884,  84957.35081494, 100758.66140315,
#          117680.57633809, 118903.79623153, 128089.08457699, 129721.29324549]),
#   'SolverCalls': 52},
#  (12, 1): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29f997cfa90>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29fecd14e10>,
#   'TotalLienarOpCall': 7197,
#   'AvgLienarOpCall': 138.40384615384616,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779868, 174505.2865836 ,
#          195025.29765846, 276755.98752008, 310231.78214388, 364313.56103686,
#          406612.51983447, 414402.77135388, 419462.56006965, 446094.86726851,
#          477204.77717031, 487072.70231668, 533802.77837708, 633085.34089832,
#          739408.86818754, 747094.58545013, 804807.45422306, 815062.92374775]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895545,
#           31039.24015031,  44047.0834441 ,  49374.92163241,  57982.30407443,
#           64714.39245471,  65954.24949195,  66759.53987707,  70998.20321371,
#           75949.49915372,  77520.02821883,  84957.3508149 , 100758.66140299,
#          117680.57633803, 118903.79623158, 128089.0845768 , 129721.29324539]),
#   'SolverCalls': 52},
#  (12, 2): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29fecd7b9e8>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29fecd67358>,
#   'TotalLienarOpCall': 2181,
#   'AvgLienarOpCall': 34.61904761904762,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658374,
#          195025.2976586 , 276755.98752016, 310231.78214403, 364313.56103724,
#          406612.51983458, 414402.77135412, 419462.56006962, 446094.86726866,
#          477204.7771701 , 487072.70231681, 533802.77837739, 633085.34089915,
#          739408.86818769, 747094.58545013, 804807.45422387, 815062.92374857]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163243,  57982.30407449,
#           64714.39245473,  65954.24949199,  66759.53987706,  70998.20321373,
#           75949.49915369,  77520.02821885,  84957.35081495, 100758.66140312,
#          117680.57633805, 118903.79623158, 128089.08457693, 129721.29324552]),
#   'SolverCalls': 63},
#  (12, 3): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29fecd7b828>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x29fecda5860>,
#   'TotalLienarOpCall': 7205,
#   'AvgLienarOpCall': 138.55769230769232,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391534,  56141.81876721, 102809.06779866, 174505.28658381,
#          195025.29765872, 276755.98751992, 310231.78214414, 364313.56103731,
#          406612.5198343 , 414402.77135419, 419462.56006952, 446094.86726875,
#          477204.77716986, 487072.70231653, 533802.77837777, 633085.34089993,
#          739408.86818728, 747094.58544896, 804807.45422361, 815062.92374711]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895548,
#           31039.24015035,  44047.08344407,  49374.92163245,  57982.3040745 ,
#           64714.39245468,  65954.249492  ,  66759.53987705,  70998.20321374,
#           75949.49915365,  77520.0282188 ,  84957.35081501, 100758.66140324,
#          117680.57633799, 118903.79623139, 128089.08457689, 129721.29324529]),
#   'SolverCalls': 52},
#  (12, 4): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x29fecdb8d68>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2a040316d68>,
#   'TotalLienarOpCall': 1792,
#   'AvgLienarOpCall': 34.46153846153846,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876722, 102809.06779866, 174505.28658375,
#          195025.2976586 , 276755.98752015, 310231.78214406, 364313.56103706,
#          406612.51983455, 414402.77135409, 419462.56006962, 446094.86726858,
#          477204.7771699 , 487072.70231686, 533802.7783774 , 633085.34089917,
#          739408.86818759, 747094.58545016, 804807.45422382, 815062.92374856]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133483,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163244,  57982.30407446,
#           64714.39245472,  65954.24949198,  66759.53987706,  70998.20321372,
#           75949.49915366,  77520.02821886,  84957.35081495, 100758.66140312,
#          117680.57633804, 118903.79623158, 128089.08457693, 129721.29324552]),
#   'SolverCalls': 52},
#  (12, 5): {'comp': <amfe.mechanical_system.MechanicalSystem at 0x2a040377940>,
#   'linearOp': <amfe.linalg.arnoldi.ProjLinearSys at 0x2a0403622b0>,
#   'TotalLienarOpCall': 52,
#   'AvgLienarOpCall': 1.0,
#   'eigenvalues': array([2.37921367e+09, 3.15190381e+09, 1.05697044e+10, 3.04520950e+10,
#          3.80348667e+10, 7.65938766e+10, 9.62437587e+10, 1.32724371e+11,
#          1.65333741e+11, 1.71729657e+11, 1.75948839e+11, 1.99000631e+11,
#          2.27724399e+11, 2.37239817e+11, 2.84945406e+11, 4.00797049e+11,
#          5.46725474e+11, 5.58150320e+11, 6.47715038e+11, 6.64327570e+11]),
#   'omega': array([ 48777.18391533,  56141.81876723, 102809.06779865, 174505.28658374,
#          195025.29765858, 276755.98752013, 310231.78214404, 364313.56103712,
#          406612.51983449, 414402.77135409, 419462.5600696 , 446094.86726859,
#          477204.77717022, 487072.70231677, 533802.77837733, 633085.34089923,
#          739408.86818753, 747094.58545006, 804807.45422396, 815062.92374847]),
#   'frequency': array([  7763.12993023,   8935.24797097,  16362.57133482,  27773.37895547,
#           31039.24015033,  44047.08344411,  49374.92163243,  57982.30407447,
#           64714.39245471,  65954.24949198,  66759.53987706,  70998.20321372,
#           75949.49915371,  77520.02821884,  84957.35081494, 100758.66140313,
#          117680.57633803, 118903.79623157, 128089.08457695, 129721.2932455 ]),
#   'SolverCalls': 52}}

# %%
def create_sector_list(my_comp,node_diam):
    sector_list = []
    for i in range(n_sector):
        sector_i = create_rotated_component(my_comp,s,sector_id=i, node_id=node_diam, theta=theta, unit='rad', dimension=3)
        sector_list.append(sector_i)
    return sector_list

def plot_sector_list(sector_list, ax1):
    ax1.clear()
    plot_list = []
    reference = True
    highlight = int(n_sector/2)
    for k,sector_i in enumerate(sector_list):
        displacement = sector_i.u_output
        m_i = sector_i.mesh_class
        if reference:
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id, facecolor=0.8*np.array((1,1,1)))    
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, 
                                      alpha=1,edgecolor=np.array((1,1,1))*0.75,linewidth=0.4,color=np.array((1,1,1)))   
                                      #alpha=1,edgecolor='black',linewidth=0.5,color=np.array((1,1,1))*0.75)   
            collections=[]
            reference = False
        else:
            
            
            #amfe.plot_system_solution(sector_i, factor=100*factor, ax = ax1, u_id = mode_id)
            pltmesh = amfe.Plot3DMesh(m_i,scale=1, displacement_list = displacement, ax = ax1, 
                                      alpha=1,edgecolor=np.array((1,1,1))*0.75,linewidth=0.4,color=np.array((1,1,1)))   
            collections = pltmesh.ax.collections
        
        if k==highlight:
            pltmesh.edgecolor='black' 
            pltmesh.linewidth=0.4,
            pltmesh.color=np.array((1,1,1))*0.75
        
        plot_list.append(pltmesh)
        
        
    return plot_list
        
precond_id = 2        
comp2new_1 = res_dict[0,precond_id]['comp']
comp2new_2 = res_dict[1,precond_id]['comp']
comp2new_3 = res_dict[2,precond_id]['comp']
sector_list_1 = create_sector_list(comp2new_1,0)
sector_list_2 = create_sector_list(comp2new_2,1)
sector_list_3 = create_sector_list(comp2new_3,2)
sector_list = [sector_list_1,
               sector_list_2,
               sector_list_3]

# %%
from ipywidgets import interact
import mpl_toolkits.mplot3d as a3

fig1 = plt.figure(figsize=(10,10))
axes_list = []
plt_list = []
counter = 0
for i in range(3):
    for j in range(3):
        ax_i = fig1.add_subplot(3,3,counter+1,projection='3d')
        axes_list.append(ax_i)
        plt_list.append(plot_sector_list(sector_list[i], ax_i))
        counter += 1
plt.rc('text', usetex=True)

#@interact(factor=(-1.0,1.0,0.05),mode_id=(0,n_modes,1))
def plot2(factor=-0.75,mode_id=0):
    #ax1.clear()
    #for sector_i in sector_list:
    #    amfe.plot_system_solution(sector_i, factor=10*factor, ax = ax1, u_id = mode_id)
    #bc = np.array([-250,250])*.6
    global bc
    i = 0
    j = 0
    for plt_list_i in plt_list:
        collections = []
        
        for plot_obj in plt_list_i:
            plot_obj.show(factor=1000*factor,plot_nodes=False,displacement_id=mode_id+i, collections=collections)
            plot_obj.set_equal_axis_lim(bc*0.7)
            plot_obj.ax.set_xlabel('x [mm]')
            plot_obj.ax.set_ylabel('y [mm]')
            plot_obj.ax.set_zlabel('z [mm]')
            #plot_obj.ax.set_title('$n$ = %i, $omega& = %f ' %(j,res_dict[j,precond_id]['omega'][i]))
            #plot_obj.ax.text(0,0,0, '$n$ = %i, $omega& = %f ' %(j,res_dict[j,precond_id]['omega'][i]))
            #label_str = r'$n$ = %i, $\omega$ = %0.2f [rad/s]' %(j,res_dict[j,precond_id]['omega'][i].real)
            label_str = r'$n$ = %i, $f$ = %0.2f [Hz]' %(j,res_dict[j,precond_id]['frequency'][i].real)
            #transform=ax.transAxes
            plot_obj.ax.text2D(0.2, 0.95, label_str, transform=plot_obj.ax.transAxes)
        if i<2:
            i+=1
        else:
            i=0
            j+=1
            
plot2(factor=-0.1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
columns = []
for i in range(len(P_n_list)):
    columns.append('ND' + str(i))
    
index = ['I','$P(incK)^{-1}P$','$PK^{-1}P$','inc(K)^-1','K^-1','(PK^P)^-1']


data = np.zeros((len(list_precond),len(P_n_list)),dtype=np.float)

for i in range(len(P_n_list)):
    for j in range(len(list_precond)):
        data[j,i] = res_dict[i,j]['AvgLienarOpCall']
        
df = pd.DataFrame(data, index=index, columns=columns)

df
# Out:
#                         ND0         ND1         ND2         ND3         ND4  \
# I                491.079365  485.555556  481.015873  474.076923  471.333333
# $P(incK)^{-1}P$   94.888889  167.015873  174.619048  201.587302  138.615385
# $PK^{-1}P$        29.952381   33.539683   33.761905   34.269841   34.500000
# inc(K)^-1         95.349206  166.555556  175.238095  201.079365  139.307692
# K^-1              29.920635   33.650794   33.777778   34.285714   34.714286
# (PK^P)^-1          1.015873    1.015873    1.000000    1.000000    1.000000
#
#                         ND5         ND6         ND7         ND8         ND9  \
# I                474.076923  480.793651  485.619048  491.349206  485.777778
# $P(incK)^{-1}P$  200.650794  173.730159  167.238095   95.936508  166.238095
# $PK^{-1}P$        34.442308   33.682540   33.603175   30.063492   33.682540
# inc(K)^-1        202.500000  173.920635  167.428571   97.063492  166.428571
# K^-1              34.384615   33.634921   33.539683   29.920635   33.682540
# (PK^P)^-1          1.000000    1.000000    1.015873    1.015873    1.015873
#
#                        ND10        ND11        ND12
# I                480.841270  474.173077  471.326923
# $P(incK)^{-1}P$  174.269841  200.698413  138.403846
# $PK^{-1}P$        33.666667   34.173077   34.619048
# inc(K)^-1        173.619048  201.809524  138.557692
# K^-1              33.539683   34.307692   34.461538
# (PK^P)^-1          1.000000    1.000000    1.000000

# %%
print('Number of dofs is equal to %i ' %K_sector.shape[0])
# Out:
# Number of dofs is equal to 1596

# %%
#fig1.savefig('3D_simple_turbine_with_24_sectors_hertz_mass_scaling.png')

# %%
from matplotlib.animation import FuncAnimation, writers
import matplotlib.animation as animation

u_list = 0.1*np.sin(np.linspace(0, 2.0*np.pi , 51 ))
ani = FuncAnimation(fig1, plot2, frames= u_list, blit=True, interval=1)   



Writer = animation.writers['imagemagick']
writer = Writer(fps=30, metadata=dict(artist='Guilherme Jenovencio'), bitrate=1000)
ani.save('3D_simple_geometry_v2.gif', dpi=400, writer=writer)
